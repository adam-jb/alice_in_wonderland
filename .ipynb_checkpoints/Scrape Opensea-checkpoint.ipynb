# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
import requests


from PIL import Image  
import cv2
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from datetime import datetime

#from bs4 import BeautifulSoup
import pytesseract
import time
from datetime import datetime

import re
from io import StringIO
import os

# %%
url = 'https://opensea.io/assets?search[sortAscending]=false&search[sortBy]=LAST_SALE_DATE'


firefox_options = Options()
firefox_options.add_argument("--headless")
driver = webdriver.Firefox(executable_path= 'geckodriver', # geckodriver runs on mac. # '/Users/dftdatascience/Downloads/geckodriver',
                         options = firefox_options)

driver.set_window_size(2000, 1200)
driver.get(url)
time.sleep(3)  # wait to ensure it defo loads


image_filename = 'current_screen.png'
print('saving file as ' + image_filename)
driver.get_screenshot_as_file(image_filename)

driver.quit()
# Out:
# saving file as current_screen.png

# %%
# cut to slightly smaller version
im = Image.open('current_screen.png')
crop_rectangle = (300,300, 2000, 1200)  # left, upper, right, lower)
cropped_im = im.crop(crop_rectangle)
cropped_im


full_text = pytesseract.image_to_string(cropped_im)

# %%
### Get usernames 
usernames = []


start_y_pixel = 200
end_y_pixel = 220
crop_rectangle = (0,start_y_pixel, 220, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))


crop_rectangle = (400,start_y_pixel, 620, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))



crop_rectangle = (720,start_y_pixel, 940, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))


crop_rectangle = (1040,start_y_pixel, 1260, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))


crop_rectangle = (1360,start_y_pixel, 1580, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))



#### 2nd row
start_y_pixel = 660
end_y_pixel = 680
crop_rectangle = (0,start_y_pixel, 220, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))


crop_rectangle = (400,start_y_pixel, 620, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))



crop_rectangle = (720,start_y_pixel, 940, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))


crop_rectangle = (1040,start_y_pixel, 1260, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))


crop_rectangle = (1360,start_y_pixel, 1580, end_y_pixel)  # left, upper, right, lower)
cropped_closer = cropped_im.crop(crop_rectangle)
usernames.append(pytesseract.image_to_string(cropped_closer))


usernames
# Out:
# ['Sacred Spiders\n\x0c',
#  '‘ZED RUN @\n\nLa\n\x0c',
#  'Robotono:\n\x0c',
#  'QXJOIEJsb2NrcyBQ.\n\n \n\x0c',
#  ' \n\x0c',
#  'QXJOIEJsb2NrcyBQ...\n\x0c',
#  'QXJOIEJsb2NrcyBQ..\n\x0c',
#  'THE REAL GOAT SOCI..\n\x0c',
#  'BillionaireZombiesc....\n\x0c',
#  'Ghoteeno\n\x0c']

# %%
### Get prices 
prices = []


start_y_pixel = 220
end_y_pixel = 240


start_x = 330
end_x = 380
for i in range(5):
    crop_rectangle = (start_x,start_y_pixel, end_x, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    prices.append(pytesseract.image_to_string(cropped_closer))
    start_x += 320
    end_x += 320


## 2nd row
start_y_pixel = 680
end_y_pixel = 700
start_x = 320
end_x = 380
for i in range(5):
    crop_rectangle = (start_x,start_y_pixel, end_x, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    prices.append(pytesseract.image_to_string(cropped_closer))
    start_x += 320
    end_x += 320


prices
# Out:
# ['3005\n\x0c',
#  '\x0c',
#  '0004\n\x0c',
#  '\x0c',
#  '\x0c',
#  '\x0c',
#  '\x0c',
#  '\x0c',
#  '\x0c',
#  '0.0004\n\x0c']

# %%
to_export = pd.DataFrame({'user':usernames,'price':prices})

now = datetime.now()
time_stamp = now.strftime("%m_%d_%Y_%H_%M_%S")

pathway = '/Users/apple/Desktop/nft/opensea_scrapings/' + time_stamp + '.csv'
to_export.to_csv(pathway)

with open('/Users/apple/Desktop/nft/opensea_scrapings/' + time_stamp + '.txt', "w") as text_file:
    text_file.write(full_text)

# %% [markdown]
# ## all the above consolidated into one process

# %%
url = 'https://opensea.io/assets?search[sortAscending]=false&search[sortBy]=LAST_SALE_DATE'


while True:
    firefox_options = Options()
    firefox_options.add_argument("--headless")
    driver = webdriver.Firefox(executable_path= 'geckodriver', # geckodriver runs on mac. # '/Users/dftdatascience/Downloads/geckodriver',
                             options = firefox_options)

    driver.set_window_size(2000, 1200)
    driver.get(url)
    time.sleep(3)  # wait to ensure it defo loads


    image_filename = 'current_screen.png'
    print('saving file as ' + image_filename)
    driver.get_screenshot_as_file(image_filename)

    driver.quit()





    # cut to slightly smaller version
    im = Image.open('current_screen.png')
    crop_rectangle = (300,300, 2000, 1200)  # left, upper, right, lower)
    cropped_im = im.crop(crop_rectangle)
    cropped_im


    # unstructured text is option 11 (full list: https://stackoverflow.com/questions/44619077/pytesseract-ocr-multiple-config-options)
    full_text = pytesseract.image_to_string(cropped_im, lang='eng', config='--psm 11')
    print(full_text)



    ### Get usernames 
    usernames = []


    start_y_pixel = 200
    end_y_pixel = 220
    crop_rectangle = (0,start_y_pixel, 220, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))


    crop_rectangle = (400,start_y_pixel, 620, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))



    crop_rectangle = (720,start_y_pixel, 940, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))


    crop_rectangle = (1040,start_y_pixel, 1260, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))


    crop_rectangle = (1360,start_y_pixel, 1580, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))



    #### 2nd row
    start_y_pixel = 660
    end_y_pixel = 680
    crop_rectangle = (0,start_y_pixel, 220, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))


    crop_rectangle = (400,start_y_pixel, 620, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))



    crop_rectangle = (720,start_y_pixel, 940, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))


    crop_rectangle = (1040,start_y_pixel, 1260, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))


    crop_rectangle = (1360,start_y_pixel, 1580, end_y_pixel)  # left, upper, right, lower)
    cropped_closer = cropped_im.crop(crop_rectangle)
    usernames.append(pytesseract.image_to_string(cropped_closer))







    ### Get prices 
    prices = []


    start_y_pixel = 220
    end_y_pixel = 240


    start_x = 330
    end_x = 380
    for i in range(5):
        crop_rectangle = (start_x,start_y_pixel, end_x, end_y_pixel)  # left, upper, right, lower)
        cropped_closer = cropped_im.crop(crop_rectangle)
        prices.append(pytesseract.image_to_string(cropped_closer))
        start_x += 320
        end_x += 320


    ## 2nd row
    start_y_pixel = 680
    end_y_pixel = 700
    start_x = 320
    end_x = 380
    for i in range(5):
        crop_rectangle = (start_x,start_y_pixel, end_x, end_y_pixel)  # left, upper, right, lower)
        cropped_closer = cropped_im.crop(crop_rectangle)
        prices.append(pytesseract.image_to_string(cropped_closer))
        start_x += 320
        end_x += 320





    to_export = pd.DataFrame({'user':usernames,'price':prices})

    now = datetime.now()
    time_stamp = now.strftime("%m_%d_%Y_%H_%M_%S")

    pathway = '/Users/apple/Desktop/nft/opensea_scrapings/' + time_stamp + '.csv'
    to_export.to_csv(pathway)

    with open('/Users/apple/Desktop/nft/opensea_scrapings/' + time_stamp + '_sparse.txt', "w") as text_file:
        text_file.write(full_text)
        
    print('exported ' + pathway)
# Out:
# saving file as current_screen.png
# Cy
#
# pea
#
# r
#
# 3)
#
# vs
#
# $
#
# fe
#
# sh
#
# ns
#
# 1 hs
#
# al
#
# Mc
#
# SS
#
# KS
#
# oe
#
# iy 2
#
# |
#
# ee
#
# He
#
# a0
#
# a
#
# 4
#
# my
#
# Ri
#
# b
#
# i
#
# ot
#
# rt
#
# es
#
# oy
#
# k
#
# i
#
# AX
#
# fl
#
# Price
#
# Ghoteeno
#
# Price
#
# Lost #35
#
# Price
#
# Best Offer
#
# The crypto zombies
#
# Art Blocks Curated
#
# Crypto Freaks World
#
# Art Blocks Curated &@
#
# The crypto zombies
#
# + 0.0004
#
# Ghoteeno #0000
#
# + 0.0004
#
# Edifice #19
#
# crypto Freak #0000
#
# + 0.0004
#
# Edifice #523
#
# $24
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Lost $4.44
#
# %
#
# %
#
# %
#
# O56
#
# 94
#
# Vo
#
# © 207
#
# Vo
#
# ¥
#
# oa
#
# a
#
# ZG
#
# 4Q
#
# 7
#
# =p
#
# ait
#
# ae
#
# 7
#
# ne)
#
# ys
#
# or
#
# (ea
#
# aaa
#
# Teo
#
# cS
#
# en
#
# Pretty Apes Club
#
# Best Offer
#
# Parallel Alpha &
#
# Price
#
# The Sculptured Apes
#
# Price
#
# Gorillas World
#
# Price
#
# Untitled Collection ..
#
# Last + 0.001
#
# 21
#
# Pretty Apes Club
#
# + 0.0005
#
# Assembly Foreman
#
# 4 0.0089
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Gorillas World (Free
#
# + 0.0004
#
# (airdrop)
#
# Last 4 0.0005
#
# Last ¢ 0.0088
#
# Airdrop
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Ov
#
# O20
#
# O98
#
# Ow
#
# Vo
#
# EEE eeEeEEEEe—=#we
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_01_51.csv
# saving file as current_screen.png
# cD
#
# yi!
#
# $
#
# is
#
# iy
#
# 1 hs
#
# al
#
# Ly
#
# Mf
#
# \S
#
# iy
#
# my
#
# fis
#
# >
#
# i wee
#
# id
#
# ~
#
# i
#
# ie
#
# la
#
# (J
#
# ott
#
# oO
#
# Hh
#
# a0
#
# 4
#
# |
#
# Pa
#
# b
#
# bs
#
# a
#
# rol
#
# Wa)
#
# Li
#
# k
#
# i
#
# la.
#
# Price
#
# Ghoteeno
#
# Price
#
# Lost #35
#
# Price
#
# Best Offer
#
# The crypto zombies
#
# Art Blocks Curated @
#
# Crypto Freaks World
#
# Art Blocks Curated @
#
# The crypto zombies
#
# + 0.0004
#
# Ghoteeno #0000
#
# + 0.0004
#
# Edifice #19
#
# crypto Freak #0000
#
# + 0.0004
#
# Edifice #523
#
# $24
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Lost $4.44
#
# %
#
# %
#
# %
#
# O56
#
# 94
#
# Vo
#
# © 207
#
# Vo
#
# ¥
#
# oa
#
# r
#
# P|
#
# ZG
#
# 4Q
#
# =p
#
# ait
#
# ae
#
# ne)
#
# ys
#
# (ea
#
# aaa
#
# Teo
#
# &
#
# en
#
# Pretty Apes Club
#
# Best Offer
#
# Parallel Alpha &
#
# Price
#
# The Sculptured Apes
#
# Price
#
# Gorillas World
#
# Price
#
# Untitled Collection ..
#
# Last + 0.001
#
# 21
#
# Pretty Apes Club
#
# + 0.0005
#
# Assembly Foreman
#
# 4 0.0089
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Gorillas World (Free
#
# + 0.0004
#
# (airdrop)
#
# Last 4 0.0005
#
# Last ¢ 0.0088
#
# Airdrop
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Ov
#
# O20
#
# O98
#
# Ow
#
# Vo
#
# EEE eeEeEEEEe—=#we
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_02_14.csv
# saving file as current_screen.png
# On
#
# it:
#
# iD
#
# B
#
# / A
#
# ,
#
# h
#
# im
#
# \~ AN
#
# eo
#
# =
#
# *
#
# Cpe
#
# AS)
#
# “a
#
# iN)
#
# Hy,
#
# WE,
#
# a> I
#
# i
#
# 4s
#
# Ve
#
# Be
#
# nk
#
# Price
#
# Robotono
#
# Price
#
# Price
#
# Million usecases ..
#
# Price
#
# Price
#
# Crypto Freaks World
#
# Screw Boys
#
# Elegant Apes Club
#
# crypto Freak #0000
#
# + 0.0004
#
# Robotono #0000
#
# + 0.0004
#
# Screw Boy #0000
#
# + 0.0004
#
# Million Rocket 001
#
# 4 0.0033
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0033
#
# Airdrop)
#
# Last 4 0.0004
#
# 9 207
#
# Or
#
# On
#
# Qu
#
# Oe
#
# a,
#
# re
#
# os
#
# ee
#
# a
#
# rt
#
# ©)
#
# oo
#
# =)
#
# wy
#
# i
#
# '¢:
#
# q
#
# G&\ }
#
# es
#
# NS
#
# “A
#
# i
#
# Fe
#
# rg
#
# {i
#
# S.
#
# ©)
#
# y I)
#
# 4\¢
#
# LN
#
# Bored Fatty
#
# Price
#
# The crypto zombies
#
# Price
#
# crypto Skull Punk
#
# Price
#
# Art Blocks Curated @
#
# Last $7.5
#
# FunApesClub
#
# Price
#
# Edifice #755
#
# Bored Fatty #000
#
# + 0.0005
#
# The crypto zombies
#
# + 0.0004
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Fun Apes Club #PROMO
#
# + 0.0004
#
# Last 40,0005,
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# 9 106
#
# e
#
# %
#
# O56
#
# Ou
#
# ivity
#
# Ou
#
# eS
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_02_35.csv
# saving file as current_screen.png
# bili
#
# Cy
#
# ia
#
# D
#
# =
#
# r
#
# cis
#
# / A
#
# NN
#
# fe
#
# Ne
#
# ee
#
# FS
#
# CS
#
# if
#
# an
#
# *
#
# |
#
# ie
#
# (
#
# 2)
#
# 1
#
# Ne
#
# cS
#
# N\\
#
# i
#
# i
#
# ay
#
# i
#
# a
#
# Oe ae!
#
# Hf
#
# s
#
# i
#
# oy
#
# J
#
# ¥
#
# ee
#
# mh
#
# Price
#
# Robotono
#
# Price
#
# Price
#
# Million usecases ..
#
# Price
#
# Price
#
# Crypto Freaks World
#
# Screw Boys
#
# Elegant Apes Club
#
# crypto Freak #0000
#
# + 0.0004
#
# Robotono #0000
#
# + 0.0004
#
# Screw Boy #0000
#
# + 0.0004
#
# Million Rocket 001
#
# 4 0.0033
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0033
#
# Airdrop)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# %
#
# 9 207
#
# Or
#
# On
#
# Qu
#
# Oe
#
# ay
#
# %
#
# mh
#
# ©)
#
# ts)
#
# re
#
# wy
#
# q
#
# G&\ }
#
# a Nef
#
# es
#
# SS
#
# ee
#
# i
#
# rg
#
# i
#
# ~~)
#
# fa
#
# y I)
#
# sil
#
# LN
#
# Bored Fatty
#
# Price
#
# The crypto zombies
#
# Price
#
# crypto Skull Punk
#
# Price
#
# Art Blocks Curated @
#
# Last 97.5
#
# FunApesClub
#
# Price
#
# Edifice #755
#
# Bored Fatty #000
#
# + 0.0005
#
# The crypto zombies
#
# + 0.0004
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Fun Apes Club #PROMO
#
# + 0.0004
#
# Last 40,0005,
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# e
#
# %
#
# 9 106
#
# e
#
# %
#
# O56
#
# e
#
# %
#
# Ou
#
# ivity
#
# e
#
# %
#
# Ou
#
# eS
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_02_58.csv
# saving file as current_screen.png
# i
#
# cof
#
# +
#
# &
#
# ‘aio
#
# \\
#
# 3
#
# 2S
#
# y
#
# Si
#
# od
#
# ea
#
# \N
#
# oS
#
# é
#
# x
#
# 2
#
# [
#
# By
#
# wil O b>
#
# aa
#
# ce
#
# a
#
# Crypto Freaks World
#
# Price
#
# Robotono
#
# Price
#
# Screw Boys
#
# Price
#
# ANillion usecases .
#
# Price
#
# Elegant Apes Club
#
# Price
#
# crypto Freak #0000
#
# + 0.0004
#
# Robotono #0000
#
# + 0.0004
#
# Screw Boy #0000
#
# + 0.0004
#
# Million Rocket 001
#
# + 0.0033
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# Last
#
# + 0.0004
#
# Last
#
# + 0.0004
#
# Last
#
# + 0.0004
#
# Last
#
# + 0.0033
#
# Airdrop)
#
# Last
#
# + 0.0004
#
# 207
#
# 2
#
# 21
#
# 24
#
# 66
#
# N
#
# ny
#
# %
#
# »
#
# a\
#
# oa
#
# 7
#
# ))
#
# iia
#
# le
#
# eN
#
# i
#
# WN \
#
# dll
#
# P
#
# el
#
# ~
#
# a
#
# Bs
#
# ag
#
# A
#
# Se
#
# ae
#
# ——~
#
# <=
#
# =
#
# om
#
# Oe
#
# ae
#
# -
#
# ne
#
# =
#
# Si
#
# fers
#
# 43
#
# aes Ps
#
# at
#
# Bored Fatty
#
# Price
#
# The crypto zombies
#
# Price
#
# Crypto Skull Punk
#
# Price
#
# Art Blocks Curated
#
# Last $7.5
#
# FunApesClub
#
# Price
#
# Edifice #755
#
# Bored Fatty #000
#
# + 0.0005
#
# The crypto zombies
#
# + 0.0004
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Fun Apes Club #PROMO
#
# + 0.0004
#
# Lost
#
# + 0.0005
#
# #0000
#
# Last
#
# + 0.0004
#
# Last
#
# + 0.0004
#
# Last
#
# + 0.0004
#
# 106
#
# 56
#
# 4a
#
# 27
#
# a
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_03_20.csv
# saving file as current_screen.png
# bili
#
# Cy
#
# ia
#
# D
#
# =
#
# r
#
# cis
#
# / A
#
# NN
#
# fe
#
# Ne
#
# ee
#
# FS
#
# CS
#
# if
#
# an
#
# *
#
# |
#
# ie
#
# (
#
# 2)
#
# 1
#
# Ne
#
# cS
#
# N\\
#
# i
#
# i
#
# ay
#
# i
#
# a
#
# Oe ae!
#
# Hf
#
# s
#
# i
#
# oy
#
# J
#
# ¥
#
# ee
#
# mh
#
# Price
#
# Robotono
#
# Price
#
# Price
#
# Million usecases ..
#
# Price
#
# Price
#
# Crypto Freaks World
#
# Screw Boys
#
# Elegant Apes Club
#
# crypto Freak #0000
#
# + 0.0004
#
# Robotono #0000
#
# + 0.0004
#
# Screw Boy #0000
#
# + 0.0004
#
# Million Rocket 001
#
# 4 0.0033
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0033
#
# Airdrop)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# %
#
# 9 207
#
# Or
#
# On
#
# Qu
#
# Oe
#
# ay
#
# %
#
# mh
#
# ©)
#
# ts)
#
# re
#
# wy
#
# q
#
# G&\ }
#
# a Nef
#
# es
#
# SS
#
# ee
#
# i
#
# rg
#
# i
#
# ~~)
#
# fa
#
# y I)
#
# sil
#
# LN
#
# Bored Fatty
#
# Price
#
# The crypto zombies
#
# Price
#
# crypto Skull Punk
#
# Price
#
# Art Blocks Curated @
#
# Last 97.5
#
# FunApesClub
#
# Price
#
# Edifice #755
#
# Bored Fatty #000
#
# + 0.0005
#
# The crypto zombies
#
# + 0.0004
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Fun Apes Club #PROMO
#
# + 0.0004
#
# Last 40,0005,
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# e
#
# %
#
# 9 106
#
# e
#
# %
#
# O56
#
# e
#
# %
#
# Ou
#
# ivity
#
# e
#
# %
#
# Ou
#
# eS
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_03_38.csv
# saving file as current_screen.png
# ae
#
# a
#
# oe
#
# \
#
# re
#
# .
#
# om
#
# \N
#
# 4
#
# om
#
# i
#
# "
#
# bs
#
# 5
#
# Ne
#
# i
#
# s
#
# iN
#
# Pretty Apes Club
#
# Last 40,0005,
#
# Dream Faes
#
# Price
#
# Party Apes Club
#
# Price
#
# Art Blocks Curated @
#
# Lost #37
#
# Parallel Alpha &
#
# Price
#
# Pretty Apes Club
#
# Muffy ~ Soft
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Edifice #404
#
# Maritus, Aetian
#
# 4 0.43
#
# Recombinant
#
# (airdrop)
#
# @3 days loft
#
# Airdrop)
#
# Last 4 0.0004
#
# @ 17 hours left
#
# %
#
# Ov
#
# %
#
# 92
#
# %
#
# On
#
# 91
#
# Om
#
# pa
#
# A
#
# ty
#
# y
#
# Ae
#
# 1
#
# we
#
# VY,
#
# <0
#
# \
#
# ©
#
# ‘A
#
# i
#
# \
#
# a
#
# gi
#
# oS
#
# ge
#
# Adopt
#
# ‘a
#
# SS
#
# PN
#
# LY
#
# ~ we
#
# : Me
#
# ca
#
# az
#
# ca
#
# a)
#
# ar
#
# 9“
#
# Robotono
#
# Price
#
# The Sculptured Apes
#
# Price
#
# Meowing Cat
#
# Price
#
# Amazing Bored Apes
#
# Price
#
# Gorillas World
#
# Price
#
# Robotono #0000
#
# Gorillas World (Free
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 40,0005,
#
# Airdrop)
#
# Last 4 0.0004
#
# e
#
# %
#
# %
#
# e
#
# %
#
# e
#
# %
#
# e
#
# %
#
# Or
#
# O98
#
# 920
#
# 9 20
#
# Ow
#
# EE
#
# a aa os cao |
#
# eS
#
# Ee ae
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_04_03.csv
# saving file as current_screen.png
# a= ©
#
# Ey
#
# Uf
#
# #
#
# \\e
#
# ue
#
# a
#
# \)
#
# i
#
# =|
#
# ie
#
# A
#
# i
#
# maa
#
# oa. eh ) ‘ ‘i
#
# Last 40,0005,
#
# Dream Faes
#
# Price
#
# Price
#
# Lost #37
#
# Price
#
# Pretty Apes Club
#
# Party Apes Club
#
# Art Blocks Curated @
#
# Parallel Alpha &
#
# Pretty Apes Club
#
# Muffy ~ Soft
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Edifice #404
#
# Maritus, Aetian
#
# 4 0.43
#
# (airdrop)
#
# @3 days loft
#
# Airdrop)
#
# Last 4 0.0004
#
# Recombinant
#
# @ 17 hours left
#
# Ov
#
# 92
#
# On
#
# 91
#
# Om
#
# ~
#
# »)
#
# iS
#
# B3
#
# fU
#
# y_
#
# y
#
# =o
#
# cz
#
# ‘ss
#
# 5
#
# w
#
# Et
#
# Oo oO
#
# KK
#
# \
#
# h
#
# be.
#
# S.
#
# ©
#
# %
#
# Adopt
#
# Cin
#
# Me! Gam
#
# y
#
# te
#
# a
#
# 2 \
#
# ) NS
#
# as
#
# oe
#
# Robotono
#
# Price
#
# ‘The Sculptured Apes
#
# Price
#
# Meowing Cat
#
# Price
#
# Amazing Bored Apes
#
# Price
#
# Gorillas World
#
# Price
#
# Robotono #0000
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# ‘Amazing Bored Apes
#
# + 0.0005
#
# Gorillas World (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 40,0005,
#
# Airdrop)
#
# Last 4 0.0004
#
# Or
#
# O98
#
# e
#
# %
#
# 920
#
# 9 20
#
# Ow
#
# eae
#
# (EE
#
# —
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_04_28.csv
# saving file as current_screen.png
# rh
#
# TT
#
# a
#
# a
#
# —=
#
# i
#
# a
#
# i
#
# ma
#
# vi
#
# LU
#
# {Pr
#
# a
#
# rN
#
# %
#
# Oe
#
# \
#
# Adopt
#
# ny
#
# ES
#
# »
#
# Price
#
# Price
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Last ¢ 0.0005
#
# Crypto Freaks World
#
# Meowing Cat
#
# Amazing Bored Apes
#
# Pretty Apes Club
#
# crypto Freak #0000
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# Catland Metaverse
#
# + 0.0005
#
# Pretty Apes Club
#
# Last ¢ 0.0004
#
# Last ¢ 0.0004
#
# (Free Apedrop)
#
# Last ¢ 0.0005
#
# Airdrop
#
# Last ¢ 0.0005
#
# (airdrop)
#
# 0
#
# 0
#
# 0
#
# 0
#
# 0
#
# Q 207
#
# 930
#
# © 200
#
# 9 69
#
# Ov
#
# S
#
# ae
#
# —).
#
# te
#
# at
#
# PY
#
# f
#
# Lcd
#
# NZ
#
# S
#
# E;
#
# ?
#
# E
#
#  N
#
# \——l
#
# D
#
# rt
#
# mia
#
# SA,
#
# i)
#
# Af
#
# h
#
# SS
#
# rd)
#
# =
#
# 1
#
# a /
#
# >
#
# .
#
# 2
#
# o>
#
# aS
#
# A
#
# aS
#
# fens
#
# Ns
#
# IN
#
# Bored Fatty
#
# Price
#
# crypto Skull Punk
#
# Price
#
# Dream Faes
#
# Price
#
# Ghoteeno
#
# Price
#
# Party Apes Club
#
# Price
#
# Ghoteeno #0000
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Muffy ~ Soft
#
# + 0.0004
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last ¢ 0.0005
#
# Last ¢ 0.0004
#
# @3 days loft
#
# Last ¢ 0.0004
#
# Airdrop)
#
# Last ¢ 0.0004
#
# 9 8
#
# O44
#
# 93
#
# 94
#
# On
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_04_51.csv
# saving file as current_screen.png
# ia
#
# OT
#
# ai
#
# [>
#
# b
#
# a
#
# 4
#
# ENN
#
# ff
#
# ty
#
# Ki
#
# 6
#
# —=
#
# a
#
# qi
#
# ew,
#
# a
#
# es
#
# Ye
#
# =
#
# 7s
#
# "2
#
# Y
#
# ys
#
# cy
#
# te
#
# =
#
# i
#
# ~ He
#
# a:
#
# >)
#
# in
#
# Wie
#
# yh
#
# y
#
# NG
#
# ot
#
# ny
#
# i
#
# »
#
# =
#
# | \
#
# Crypto Freaks World
#
# Price
#
# Meowing Cat
#
# Price
#
# Amazing Bored Apes
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Pretty Apes Club
#
# Last 4 0.0005
#
# crypto Freak #0000
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# Catland Metaverse
#
# + 0.0005
#
# Pretty Apes Club
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 4 0.0005
#
# Airdrop
#
# Last 4 0.0005
#
# (airdrop)
#
# Q 207
#
# 930
#
# © 200
#
# 9 69
#
# Ov
#
# =
#
# We
#
# ry
#
# \
#
# oPa
#
# a
#
# mn |,
#
# Xx
#
# A
#
# ~~
#
# 5)
#
# hg
#
# <—
#
# (yA
#
# oO)
#
# Se
#
# DSA
#
# y
#
# h
#
# Y
#
# 4
#
# nt
#
# Z
#
# \k
#
# —)
#
# ae
#
# ye
#
# aN
#
# i,
#
# SS
#
# Ny
#
# Se:
#
# ae
#
# xa
#
# SS
#
# ss
#
# re,
#
# ear
#
# il
#
# Bored Fatty
#
# Price
#
# crypto Skull Punk
#
# Price
#
# Dream Faes
#
# Price
#
# Ghoteeno
#
# Price
#
# Party Apes Club
#
# Price
#
# Ghoteeno #0000
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Muffy ~ Soft
#
# + 0.0004
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# @3 days loft
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# 0
#
# 0
#
# 0
#
# 0
#
# 0
#
# 9 8
#
# O44
#
# 93
#
# 94
#
# On
#
# EE
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_05_14.csv
# saving file as current_screen.png
# Oey
#
# ait
#
# 2D
#
# Ue:
#
# mY,
#
# Hr
#
# ay
#
# ul
#
# L
#
# L
#
# ed
#
# Bis sé
#
# al
#
# pe
#
# IN
#
# By
#
# B
#
# y
#
# ri
#
# yy)
#
# ow
#
# es
#
# i
#
# WG.
#
# ‘
#
# Price
#
# Price
#
# Best Offer
#
# The Mask Punks
#
# Price
#
# Price
#
# Baby Apes City
#
# Crypto Freaks World
#
# Pretty Apes Club
#
# Crytho Punks
#
# Baby Apes City (Free
#
# + 0.0005
#
# crypto Freak #0000
#
# + 0.0004
#
# Pretty Apes Club
#
# + 0.0005
#
# Mask Punks #Promo
#
# + 0.0004
#
# rytho Punks #0000
#
# + 0.0005
#
# Airdrop)
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# (airdrop)
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# n
#
# 207
#
# 7
#
# 116
#
# 19
#
# =_—— ~
#
# Bs
#
# gs
#
# i
#
# ff
#
# Se
#
# ra
#
# ig
#
# ive
#
# Y
#
# i
#
# QE,
#
# Ne
#
# SS
#
# ===
#
# ———
#
# -
#
# i,
#
# se
#
# pret
#
# 4
#
# om
#
# =
#
# =a
#
# i
#
# res.
#
# 5
#
# ———=
#
# ne
#
# The Sculptured Apes
#
# Price
#
# Bored Fatty
#
# Price
#
# Art Blocks Curated
#
# Best Offer
#
# Crypto Skull Punk
#
# Price
#
# Scary Ghosts Club
#
# Price
#
# Edifice #444
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# $24
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Scary Ghosts (Airdrop,
#
# + 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# Lost 4 3.75
#
# Last 4 0.0004
#
# mint chance 5%)
#
# Last 4 0.0004
#
# 98
#
# 106
#
# 4a
#
# 16
#
# Pe
#
# EEE
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_05_38.csv
# saving file as current_screen.png
# yi
#
# ro
#
# ae
#
# 2}
#
# ey
#
# (Ck
#
# HY i
#
# a
#
# ‘i
#
# Wi
#
# \
#
# -
#
# ey
#
# s
#
# ys
#
# ld
#
# ,
#
# INN
#
# 8 |
#
# pee"
#
# 4
#
# . a
#
# i
#
# i
#
# vy
#
# i
#
# ar}
#
# i
#
# Si
#
# = he
#
# os
#
# 1
#
# “
#
# .
#
# "
#
# Price
#
# Price
#
# Best Offer
#
# The Mask Punks
#
# Price
#
# Price
#
# Baby Apes City
#
# Crypto Freaks World
#
# Pretty Apes Club
#
# crytho Punks
#
# Baby Apes City (Free
#
# + 0.0005
#
# crypto Freak #0000
#
# + 0.0004
#
# Pretty Apes Club
#
# + 0.0005
#
# Mask Punks #Promo
#
# + 0.0004
#
# rytho Punks #0000
#
# + 0.0005
#
# Airdrop)
#
# Last 40,0005,
#
# Last 4 0.0004
#
# (airdrop)
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Last 40,0005,
#
# %
#
# %
#
# e
#
# %
#
# %
#
# On
#
# 9 207
#
# Ov
#
# 8
#
# O16
#
# Ow
#
# =
#
# 7
#
# «
#
# 2
#
# is
#
# pa
#
# (ML
#
# /
#
# bie
#
# Rr
#
# 4
#
# 2
#
# OZ)
#
# Dk
#
# Ne
#
# INS
#
# ati
#
# A
#
# SS
#
# ops
#
# ee
#
# aS
#
# a
#
# 4
#
# =
#
# =
#
# Fe
#
# 4n(
#
# The Sculptured Apes
#
# Price
#
# Bored Fatty
#
# Price
#
# Art Blocks Curated @
#
# Best Offer
#
# crypto Skull Punk
#
# Price
#
# Scary Ghosts Club
#
# Price
#
# Edifice #444
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# $24
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Scary Ghosts (Airdrop,
#
# + 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Last 40,0005,
#
# Lost $3.75,
#
# Last 4 0.0004
#
# mint chance 5%)
#
# Last 4 0.0004
#
# e
#
# %
#
# O98
#
# e
#
# %
#
# 9 106
#
# Vo
#
# e
#
# %
#
# Ou
#
# e
#
# %
#
# O16
#
# Pe
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_06_01.csv
# saving file as current_screen.png
# yi
#
# ro
#
# ae
#
# ey
#
# 4
#
# HY i
#
# ‘i
#
# Wi
#
# \
#
# 4
#
# oh
#
# -
#
# ey
#
# ld
#
# 4
#
# ,
#
# ai
#
# INN
#
# ==
#
# pee"
#
# 4
#
# a
#
# a
#
# . a
#
# a.
#
# i
#
# i
#
# vy
#
# i
#
# i
#
# Si
#
# here
#
# ap
#
# BY
#
# os
#
# 1
#
# “
#
# .
#
# "
#
# Price
#
# Price
#
# Best Offer
#
# The Mask Punks
#
# Price
#
# Price
#
# Baby Apes City
#
# Crypto Freaks World
#
# Pretty Apes Club
#
# crytho Punks
#
# Baby Apes City (Free
#
# + 0.0005
#
# crypto Freak #0000
#
# + 0.0004
#
# Pretty Apes Club
#
# + 0.0005
#
# Mask Punks #Promo
#
# + 0.0004
#
# rytho Punks #0000
#
# + 0.0005
#
# Airdrop)
#
# Last 40,0005,
#
# Last 4 0.0004
#
# (airdrop)
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Last 40,0005,
#
# %
#
# %
#
# e
#
# %
#
# %
#
# On
#
# 9 207
#
# Ov
#
# 8
#
# O16
#
# Ow
#
# «
#
# 2
#
# is
#
# pa
#
# (ML
#
# /
#
# bie
#
# Rr
#
# 4
#
# 2
#
# OZ)
#
# Dk
#
# Ne
#
# INS
#
# ati
#
# A
#
# ‘
#
# SS
#
# y
#
# mI
#
# =
#
# my
#
# Sse
#
# =
#
# ee
#
# =
#
# ss
#
# 4
#
# =
#
# =
#
# é.
#
# ral
#
# The Sculptured Apes
#
# Price
#
# Bored Fatty
#
# Price
#
# Art Blocks Curated @
#
# Best Offer
#
# crypto Skull Punk
#
# Price
#
# Scary Ghosts Club
#
# Price
#
# Edifice #444
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# $24
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Scary Ghosts (Airdrop,
#
# + 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Last 40,0005,
#
# Lost $3.75,
#
# Last 4 0.0004
#
# mint chance 5%)
#
# Last 4 0.0004
#
# e
#
# %
#
# O98
#
# e
#
# %
#
# 9 106
#
# Vo
#
# e
#
# %
#
# Ou
#
# e
#
# %
#
# O16
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_06_24.csv
# saving file as current_screen.png
# 2}
#
# Rye
#
# (Ck
#
# oem
#
# wW
#
# a
#
# )
#
# a
#
# 4
#
# s
#
# 8 |
#
# tg
#
# q
#
# 4
#
# OD
#
# c
#
# fe)
#
# ar}
#
# aaah
#
# = he
#
# N
#
# Price
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Best Offer
#
# The Sculptured Apes
#
# The crypto zombies
#
# Tigers Deluxe Club
#
# Pretty Apes Club
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Pretty Apes Club
#
# + 0.0005
#
# Airdrop
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# (airdrop)
#
# Last 40,0005,
#
# %
#
# %
#
# %
#
# %
#
# O98
#
# O56
#
# 8
#
# O16
#
# Vs
#
# Ov
#
# \\
#
# i
#
# 6
#
# Mie
#
# Ww
#
# iv
#
# a
#
# ©
#
# ii
#
# ("Pa
#
# —
#
# AVA(
#
# @Q =
#
# “
#
# (5
#
# 5
#
# mh
#
# SS:
#
# YG,
#
# —
#
# y
#
# ae
#
# i
#
# or)
#
# os
#
# (4
#
# >!
#
# x
#
# fy
#
# De
#
# Adopt
#
# D)
#
# Sy
#
# a
#
# Me! &
#
# Or
#
# Z,)
#
# Tow)
#
# =
#
# La
#
# ey 2)
#
# Baby Kids Apes
#
# Price
#
# crytho Punks
#
# Price
#
# Meowing Cat
#
# Price
#
# Gorillas World
#
# Price
#
# Bored Fatty
#
# Price
#
# Baby Kids Apes (Free
#
# + 0.0005
#
# rytho Punks #0000
#
# + 0.0005
#
# Meowing Cat #000
#
# + 0.0004
#
# Gorillas World (Free
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Airdrop)
#
# Last 40,0005,
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 40,0005,
#
# e
#
# %
#
# O39
#
# e
#
# %
#
# Ow
#
# e
#
# %
#
# 920
#
# e
#
# %
#
# Ow
#
# e
#
# %
#
# 9 106
#
# P|
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_06_48.csv
# saving file as current_screen.png
# 2}
#
# eee
#
# Rye
#
# (Ck
#
# a
#
# We
#
# F
#
# 7
#
# OM)
#
# ‘)
#
# 4
#
# s
#
# ak
#
# ee y
#
# iN
#
# oe
#
# Ss
#
# ar}
#
# Se:
#
# >
#
# = he
#
# 2
#
# Pal
#
# =~
#
# st \
#
# Price
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Best Offer
#
# The Sculptured Apes
#
# The crypto zombies
#
# Tigers Deluxe Club
#
# Pretty Apes Club
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Pretty Apes Club
#
# + 0.0005
#
# Airdrop
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# (airdrop)
#
# Last 4 0.0005
#
# %
#
# %
#
# %
#
# %
#
# O98
#
# O56
#
# 8
#
# O16
#
# Vs
#
# Ov
#
# Bes
#
# ae
#
# \\
#
# ~
#
# hms
#
# Ww
#
# Na
#
# ©
#
# W/
#
# AVA(
#
# (Gy
#
# YG,
#
# y
#
# a
#
# Fin
#
# or)
#
# a
#
# ;
#
# a
#
# x
#
# fo
#
# Adopt
#
# Sy
#
# Me! &
#
# h)
#
# vd
#
# UG
#
# 22
#
# =
#
# La
#
# ey 2)
#
# Baby Kids Apes
#
# Price
#
# crytho Punks
#
# Price
#
# Meowing Cat
#
# Price
#
# Gorillas World
#
# Price
#
# Bored Fatty
#
# Price
#
# Baby Kids Apes (Free
#
# + 0.0005
#
# rytho Punks #0000
#
# + 0.0005
#
# Meowing Cat #000
#
# + 0.0004
#
# Gorillas World (Free
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Airdrop)
#
# Last 4 0.0005
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# e
#
# %
#
# O39
#
# e
#
# %
#
# Ow
#
# e
#
# %
#
# 920
#
# e
#
# %
#
# Ow
#
# e
#
# %
#
# 9 106
#
# P|
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_07_12.csv
# saving file as current_screen.png
# 2}
#
# Rye
#
# C
#
# EB
#
# wW
#
# a
#
# F
#
# 7
#
# iw wy
#
# 4
#
# s
#
# ee y
#
# 4
#
# Ss
#
# Ve
#
# =a}
#
# <i
#
# Se:
#
# >
#
# = he
#
# OA
#
# La
#
# Price
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Best Offer
#
# The Sculptured Apes
#
# The crypto zombies
#
# Tigers Deluxe Club
#
# Pretty Apes Club
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Pretty Apes Club
#
# + 0.0005
#
# Airdrop
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# (airdrop)
#
# Last 4 0.0005
#
# %
#
# %
#
# %
#
# %
#
# O98
#
# O56
#
# 8
#
# O16
#
# Vs
#
# Ov
#
# Bes
#
# ae
#
# -
#
# hms
#
# we
#
# 7)
#
# Na
#
# oe
#
# W/
#
# bre
#
# AVA(
#
# if
#
# YG,
#
# y
#
# a
#
# Fin
#
# or)
#
# nil
#
# ;
#
# fo
#
# crt)
#
# Adopt
#
# Fa
#
# Me! &
#
# h)
#
# UG
#
# 22
#
# =
#
# La
#
# ey 2)
#
# Baby Kids Apes
#
# Price
#
# crytho Punks
#
# Price
#
# Meowing Cat
#
# Price
#
# Gorillas World
#
# Price
#
# Bored Fatty
#
# Price
#
# Baby Kids Apes (Free
#
# + 0.0005
#
# rytho Punks #0000
#
# + 0.0005
#
# Meowing Cat #000
#
# + 0.0004
#
# Gorillas World (Free
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Airdrop)
#
# Last 4 0.0005
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# e
#
# %
#
# O39
#
# e
#
# %
#
# Ow
#
# e
#
# %
#
# 920
#
# e
#
# %
#
# Ow
#
# e
#
# %
#
# 9 106
#
# P|
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_07_35.csv
# saving file as current_screen.png
# 2}
#
# Cy
#
# \Se
#
# (Ck
#
# ——_
#
# a
#
# cn
#
# es
#
# iy
#
# Wi
#
# Z
#
# }
#
# \—
#
# 1
#
# ——
#
# K
#
# if
#
# IS
#
# NS
#
# mx
#
# fs,
#
# 8 |
#
# i
#
# ES
#
# a
#
# ae
#
# Vs
#
# ‘i
#
# ar}
#
# )
#
# OI
#
# in
#
# = he
#
# i
#
# ESO
#
# ei
#
# 1
#
# me
#
# Robotono
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Price
#
# Price
#
# The Sculptured Apes
#
# Crypto Freaks World
#
# Party Apes Club
#
# Robotono #0000
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# crypto Freak #0000
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# Or
#
# 8
#
# O16
#
# O98
#
# 9 207
#
# On
#
# Ze
#
# y
#
# 3
#
# =
#
# ~~
#
# as
#
# 4
#
# Sy
#
# SS
#
# ay
#
# ae
#
# )
#
# i\
#
# q
#
# WV
#
# 7
#
# eZ
#
# A)
#
# iS
#
# 4
#
# SQ
#
# Be)
#
# fe)
#
# 9
#
# al
#
# Lt)
#
# ay)
#
# 44
#
# Ghoteeno
#
# Price
#
# 3DPunks2D
#
# Price
#
# The crypto zombies
#
# Price
#
# Amazing Bored Apes
#
# Price
#
# Tigers Deluxe Club
#
# Price
#
# Ghoteeno #0000
#
# + 0.0004
#
# apPunks20 (AirDrop)
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 40,0005,
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# e
#
# %
#
# 94
#
# e
#
# %
#
# Oa
#
# e
#
# %
#
# O56
#
# e
#
# %
#
# O20
#
# e
#
# %
#
# Vs
#
# P|
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_07_59.csv
# saving file as current_screen.png
# Woe
#
# OO
#
# NIT
#
# i
#
# [4
#
# EY =
#
# |
#
# Ri
#
# 5
#
# i
#
# ~S
#
# San
#
# Y,
#
# 1)
#
# Ke
#
# 588)
#
# ps
#
# he ie
#
# CF
#
# fa
#
# ye
#
# 1}
#
# i
#
# Gil
#
# “7
#
# i
#
# a!
#
# Robotono
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Price
#
# Price
#
# The Sculptured Apes
#
# Crypto Freaks World
#
# Party Apes Club
#
# Robotono #0000
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# crypto Freak #0000
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# Or
#
# 8
#
# O16
#
# O98
#
# © 207
#
# On
#
# e
#
# —
#
# (7)
#
# 3
#
# ———_
#
# a
#
# GE
#
# Ss
#
# 4
#
# Nae
#
# Ss
#
# 5
#
# ay
#
# a
#
# )
#
# i\
#
# q
#
# my
#
# ne
#
# a
#
# Z
#
# Za \\
#
# 4
#
# OD
#
# Ve
#
# Cee
#
# if
#
# <i
#
# re
#
# OA
#
# La
#
# Ghoteeno
#
# Price
#
# 3DPunks2D
#
# Price
#
# The crypto zombies
#
# Price
#
# Amazing Bored Apes
#
# Price
#
# Tigers Deluxe Club
#
# Price
#
# Ghoteeno #0000
#
# + 0.0004
#
# apPunks20 (AirDrop)
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 4 0.0005
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# 94
#
# Qa
#
# O56
#
# O20
#
# Vs
#
# GE... 72-
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_08_23.csv
# saving file as current_screen.png
# 2}
#
# Cy
#
# \Se
#
# (Ck
#
# ——_
#
# a
#
# cn
#
# es
#
# y
#
# Wi
#
# Z
#
# }
#
# =
#
# 1
#
# ——
#
# 8&@e
#
# s
#
# if
#
# I
#
# ee y
#
# iN
#
# ‘
#
# ul
#
# ar}
#
# )
#
# RL
#
# EA |
#
# ult
#
# = he
#
# i
#
# ESO
#
# ei
#
# me
#
# Robotono
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Price
#
# Price
#
# The Sculptured Apes
#
# Crypto Freaks World
#
# Party Apes Club
#
# Robotono #0000
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# crypto Freak #0000
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# Or
#
# 8
#
# O16
#
# O98
#
# 9 207
#
# On
#
# Ze
#
# y
#
# —
#
# Co)
#
# 3
#
# ‘=
#
# a
#
# Ts
#
# =
#
# 4
#
# (al
#
# \_ i)
#
# Ss
#
# 5
#
# coe
#
# 7
#
# ae
#
# )
#
# i\
#
# q
#
# AVY
#
# 2%
#
# 7
#
# OA
#
# 4
#
# OD
#
# Tl
#
# EG
#
# re
#
# ey
#
# <i
#
# Fal
#
# OA
#
# La
#
# Ghoteeno
#
# Price
#
# 3DPunks2D
#
# Price
#
# The crypto zombies
#
# Price
#
# Amazing Bored Apes
#
# Price
#
# Tigers Deluxe Club
#
# Price
#
# Ghoteeno #0000
#
# + 0.0004
#
# apPunks20 (AirDrop)
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 4 0.0005
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# e
#
# %
#
# 94
#
# e
#
# %
#
# Oa
#
# e
#
# %
#
# O56
#
# e
#
# %
#
# O20
#
# e
#
# %
#
# Vs
#
# P|
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_08_47.csv
# saving file as current_screen.png
# - |
#
# ‘ef
#
# [et
#
# J
#
# Ky
#
# Wo.
#
# i
#
# yp
#
# Sy
#
# — Me
#
# wo
#
# r
#
# Adopt
#
# fi
#
# io
#
# Me! &
#
# rao.
#
# oS
#
# AN
#
# i}
#
# ¢
#
# i
#
# i)
#
# °
#
# Pa
#
# ]
#
# Sai
#
# ——
#
# ba
#
# EB
#
# Price
#
# Price
#
# Price
#
# Price
#
# Price
#
# Meowing Cat
#
# Angry Apes Collecti...
#
# Bored Fatty
#
# crypto Skull Punk
#
# Amazing Bored Apes
#
# Meowing Cat #000
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 4 0.0005
#
# e
#
# %
#
# %
#
# %
#
# %
#
# %
#
# 920
#
# Ox
#
# 9 106
#
# Ou
#
# O20
#
# pa
#
# iN
#
# Ri
#
# a
#
# 7
#
# %
#
# iON
#
# %
#
# 4
#
# a
#
# a»
#
# Se
#
# Bd
#
# “ 7.
#
# Pretty Apes Club
#
# Last 4 0.0005
#
# The crypto zombies
#
# Price
#
# Ghoteeno
#
# Price
#
# FinFractual
#
# Last 4 0.0006
#
# The Sculptured Apes
#
# Price
#
# Ghoteeno #0000
#
# Pretty Apes Club
#
# The crypto zombies
#
# + 0.0004
#
# + 0.0004
#
# Fractal #147 Spring Royal
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# (airdrop)
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# e
#
# %
#
# Ov
#
# %
#
# O56
#
# e
#
# %
#
# 94
#
# e
#
# %
#
# 91
#
# e
#
# %
#
# O98
#
# ET!
#
# a aa os cao |
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_09_11.csv
# saving file as current_screen.png
# [et
#
# J
#
# Ky
#
# Wo.
#
# Sy
#
# il
#
# C
#
# a
#
# \y
#
# r
#
# a
#
# Adopt
#
# a
#
# io
#
# ; Me! &
#
# AN
#
# i}
#
# .
#
# Ra
#
# Pa
#
# ]
#
# Sai
#
# ——
#
# fa
#
# ‘ EB
#
# Price
#
# Price
#
# Price
#
# Price
#
# Price
#
# Meowing Cat
#
# Angry Apes Collecti...
#
# Bored Fatty
#
# crypto Skull Punk
#
# Amazing Bored Apes
#
# Meowing Cat #000
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 4 0.0005
#
# e
#
# %
#
# %
#
# %
#
# %
#
# %
#
# 920
#
# Ox
#
# 9 106
#
# Ou
#
# O20
#
# pa
#
# XN lO
#
# a
#
# F
#
# 7
#
# a
#
# %
#
# iON
#
# %
#
# 4
#
# a
#
# y Ns
#
# Se
#
# 4
#
# “ 7.
#
# Pretty Apes Club
#
# Last 4 0.0005
#
# The crypto zombies
#
# Price
#
# Ghoteeno
#
# Price
#
# FinFractual
#
# Last 4 0.0006
#
# The Sculptured Apes
#
# Price
#
# Ghoteeno #0000
#
# Pretty Apes Club
#
# The crypto zombies
#
# + 0.0004
#
# + 0.0004
#
# Fractal #147 Spring Royal
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# (airdrop)
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# e
#
# %
#
# Ov
#
# e
#
# %
#
# O56
#
# e
#
# %
#
# 94
#
# e
#
# %
#
# 91
#
# e
#
# %
#
# O98
#
# ET!
#
# Se ee |
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_09_34.csv
# saving file as current_screen.png
# J
#
# Wo.
#
# il
#
# f
#
# tC
#
# a.
#
# ‘a
#
# nN
#
# cd
#
# Wi
#
# Adopt
#
# a
#
# ; Me! &
#
# DANY
#
# i}
#
# °
#
# S
#
# a
#
# aaa
#
# Pa
#
# f=
#
# Sh
#
# ba
#
# EB
#
# SS
#
# Price
#
# Price
#
# Price
#
# Price
#
# Price
#
# Meowing Cat
#
# Angry Apes Collecti..
#
# Bored Fatty
#
# crypto Skull Punk
#
# Amazing Bored Apes
#
# Meowing Cat #000
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Amazing Bored Apes
#
# + 0.0005
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# (Free Apedrop)
#
# Last 4 0.0005
#
# %
#
# %
#
# %
#
# %
#
# %
#
# 920
#
# Ox
#
# 9 106
#
# Ou
#
# O20
#
# Uf
#
# hI
#
# oa
#
# &
#
# lO
#
# aN
#
# Ri
#
# =p
#
# Runes
#
# 1
#
# %
#
# iON
#
# %
#
# S
#
# my
#
# la
#
# hea oa
#
# ba)
#
# ys
#
# Pa
#
# kaa
#
# i
#
# a
#
# Pretty Apes Club
#
# Last 4 0.0005
#
# The crypto zombies
#
# Price
#
# Ghoteeno
#
# Price
#
# FinFractual
#
# Last 4 0.0006
#
# The Sculptured Apes
#
# Price
#
# Ghoteeno #0000
#
# Pretty Apes Club
#
# The crypto zombies
#
# + 0.0004
#
# + 0.0004
#
# Fractal #147 Spring Royal
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# (airdrop)
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Ov
#
# O56
#
# 94
#
# 91
#
# O98
#
# a aa os cao |
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_09_57.csv
# saving file as current_screen.png
# QO)
#
# a
#
# Nae
#
# ae
#
# /
#
# K
#
# eo
#
# Ado)
#
# 4
#
# SQ
#
# P
#
# ‘
#
# nd
#
# fe)
#
# Z
#
# Me! Wm
#
# a
#
# Gj
#
# 44
#
# Se
#
# TY
#
# Robotono
#
# Price
#
# Price
#
# Surreal Man
#
# Price
#
# Price
#
# The Mask Punks
#
# Price
#
# Tigers Deluxe Club
#
# Meowing Cat
#
# Robotono #0000
#
# + 0.0004
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Surreal Man #000
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Or
#
# Vs
#
# O56
#
# 920
#
# O16
#
# a.
#
# ee
#
# Pe
#
# 5
#
# si
#
# TE yiat
#
# Z
#
# @Q =
#
# eA
#
# ba
#
# B
#
# MI
#
# la
#
# / iN
#
# ‘
#
# of
#
# —
#
# ie
#
# T
#
# +
#
# ane
#
# jen
#
# 5
#
# a |
#
# las
#
# t
#
# crytho Punks
#
# Price
#
# Sipherian Flash
#
# Best Offer
#
# Bored Fatty
#
# Price
#
# crypto Skull Punk
#
# Price
#
# Elegant Apes Club
#
# Price
#
# 202
#
# rytho Punks #0000
#
# + 0.0005
#
# + 0.135
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# Last 40,0005,
#
# Last $ 015
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Ow
#
# Vo
#
# 9 106
#
# Ou
#
# Oe
#
# a
#
# SE!
#
# eS
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_10_21.csv
# saving file as current_screen.png
# r=
#
# wW
#
# ~—
#
# \
#
# CI
#
# aD
#
# 6a
#
# ny
#
# a
#
# a
#
# u
#
# Be
#
# ome
#
# \
#
# Adopt
#
# ee
#
# ——
#
# ; Me! Wm
#
# i
#
# \
#
# -
#
# a oe
#
# Robotono
#
# Price
#
# Price
#
# Surreal Man
#
# Price
#
# Price
#
# The Mask Punks
#
# Price
#
# Tigers Deluxe Club
#
# Meowing Cat
#
# Robotono #0000
#
# + 0.0004
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Surreal Man #000
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# 0
#
# 0
#
# On
#
# V8
#
# QO 56
#
# 930
#
# O16
#
# oie
#
# SE
#
# >
#
# ma
#
# »))
#
# a
#
# me
#
# is
#
# \
#
# id
#
# /
#
# .;
#
# D
#
# cy
#
# ra
#
# ye
#
# fa.
#
# a
#
# NY :
#
# Crytho Punks
#
# Price
#
# Sipherian Flash
#
# Best Offer
#
# Bored Fatty
#
# Price
#
# Crypto Skull Punk
#
# Price
#
# Elegant Apes Club
#
# Price
#
# 292,
#
# rytho Punks #0000
#
# + 0.0005
#
# 4 0.135
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0005
#
# Last 4 016
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# On
#
# 91
#
# 9 8
#
# O44
#
# O66
#
# A
#
# SE!
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_10_44.csv
# saving file as current_screen.png
# QO)
#
# a
#
# Nae
#
# ae
#
# =~
#
# K
#
# "
#
# eo
#
# 4
#
# SQ
#
# Adopt
#
# nd
#
# fe)
#
# Z
#
# ; Me! &
#
# a
#
# Gj
#
# 44
#
# Se
#
# TY
#
# Robotono
#
# Price
#
# Price
#
# Surreal Man
#
# Price
#
# Price
#
# The Mask Punks
#
# Price
#
# Tigers Deluxe Club
#
# Meowing Cat
#
# Robotono #0000
#
# + 0.0004
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Surreal Man #000
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Or
#
# Vs
#
# O56
#
# 920
#
# O16
#
# a.
#
# ee
#
# Pe
#
# 5
#
# si
#
# TE yiat
#
# Z
#
# a
#
# @Q =
#
# eA
#
# ba
#
# B
#
# MI
#
# ‘
#
# of
#
# —
#
# ie
#
# T
#
# y
#
# ane
#
# jen
#
# 5
#
# a |
#
# las
#
# t
#
# crytho Punks
#
# Price
#
# Sipherian Flash
#
# Best Offer
#
# Bored Fatty
#
# Price
#
# crypto Skull Punk
#
# Price
#
# Elegant Apes Club
#
# Price
#
# 202
#
# rytho Punks #0000
#
# + 0.0005
#
# + 0.135
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# Last 40,0005,
#
# Last $ 015
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Ow
#
# 91
#
# 9 106
#
# Ou
#
# Oe
#
# a
#
# SE!
#
# eS
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_11_07.csv
# saving file as current_screen.png
# a
#
# We
#
# CO
#
# bis
#
# \
#
# v
#
# ql
#
# qi
#
# ff
#
# ae
#
# _
#
# i
#
# \
#
# Ne
#
# bil,
#
# iS
#
# Pu
#
# e
#
# =o
#
# aS
#
# 53
#
# fe
#
# —
#
# SSS ch)
#
# »
#
# Adopt
#
# eh
#
# Tam: Me! |
#
# A
#
# ty
#
# i
#
# _
#
# ay
#
# i
#
# Sh
#
# L ==
#
# Price
#
# Price
#
# Price
#
# Price
#
# Price
#
# crytho Punks
#
# Meowing Cat
#
# Bored Fatty
#
# crypto Skull Punk
#
# Crypto Freaks World
#
# rytho Punks #0000
#
# + 0.0005
#
# Meowing Cat #000
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# crypto Freak #0000
#
# + 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# %
#
# On
#
# 930
#
# 9 8
#
# O44
#
# Q 207
#
# |
#
# i
#
# —*s
#
# Nt)
#
# Pe
#
# ye
#
# 2
#
# 0.
#
# 0x0"
#
# =
#
# H
#
# )
#
# CS
#
# y
#
# >|
#
# TJ
#
# g
#
# it
#
# ye
#
# by
#
# S:
#
# oy
#
# oS
#
# Pode
#
# Spy
#
# si
#
# ><
#
# W
#
# PZ
#
# O10)
#
# oh
#
# Zi
#
# N
#
# aed
#
# ‘
#
# I
#
# S
#
# u
#
# KO A)
#
# 1
#
# Wy
#
# J
#
# SS
#
# MR
#
# @
#
# Amazing Bored Apes
#
# Price
#
# Pretty Apes Club
#
# Last 4 0.0005
#
# Gorillas World
#
# Price
#
# Robotono
#
# Price
#
# Tigers Deluxe Club
#
# Price
#
# Robotono #0000
#
# Amazing Bored Apes
#
# + 0.0005
#
# Pretty Apes Club
#
# Gorillas World (Free
#
# + 0.0004
#
# + 0.0004
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# (Free Apedrop)
#
# Last 4 0.0005
#
# (airdrop)
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# 9 201
#
# Ov
#
# On
#
# On
#
# V8
#
# i
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_11_30.csv
# saving file as current_screen.png
# F)
#
# b
#
# Sar
#
# ai
#
# ieee
#
# a
#
# ll
#
# aK
#
# upping
#
# ty
#
# pe
#
# a
#
# %.
#
# Onn
#
# ew,
#
# a
#
# A
#
# =
#
# —s
#
# =
#
# ’
#
# ee
#
# a
#
# 5?
#
# i
#
# ".
#
# =
#
# nt
#
# \
#
# 4
#
# rs
#
# NS
#
# a:
#
# (eo)
#
# ZA
#
# —
#
# —
#
# ae
#
# vi
#
# A
#
# =
#
# wn
#
# he}
#
# eX
#
# =
#
# i
#
# y
#
# 2
#
# a‘
#
# a
#
# is
#
# an
#
# Ze
#
# So,
#
# “ih
#
# Crytho Punks
#
# Price
#
# Meowing Cat
#
# Price
#
# Bored Fatty
#
# Price
#
# Crypto Skull Punk
#
# Price
#
# Crypto Freaks World
#
# Price
#
# rytho Punks #0000
#
# + 0.0005
#
# Meowing Cat #000
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# crypto Freak #0000
#
# + 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# On
#
# 930
#
# © 106
#
# O44
#
# Q 207
#
# ee
#
# a
#
# )
#
# Ee
#
# @
#
# ”
#
# &
#
# 4
#
# ee
#
# yf
#
# AS
#
# ‘a
#
# .o
#
# aS
#
# rN
#
# ae all
#
# A
#
# ee
#
# Amazing Bored Apes
#
# Price
#
# Pretty Apes Club
#
# Last 4 0.0005
#
# Gorillas World
#
# Price
#
# Robotono
#
# Price
#
# Tigers Deluxe Club
#
# Price
#
# Gorillas World (Free
#
# Robotono #0000
#
# Amazing Bored Apes
#
# + 0.0005
#
# Pretty Apes Club
#
# + 0.0004
#
# + 0.0004
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# (Free Apedrop)
#
# Last 4 0.0005
#
# (airdrop)
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# 0
#
# 0
#
# 0
#
# 0
#
# 0
#
# 9 201
#
# Ov
#
# On
#
# On
#
# V8
#
# a
#
# ra
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_11_53.csv
# saving file as current_screen.png
# oe
#
# S
#
# >
#
# ‘,
#
# »)
#
# ell
#
# i
#
# ex
#
# eo’
#
# fs
#
# a
#
# is
#
# .
#
# ef
#
# om |
#
# -
#
# =
#
# its
#
# = 5
#
# Gorillas World
#
# Price
#
# Meowing Cat
#
# Price
#
# Pretty Apes Club
#
# Last
#
# + 0.0005
#
# The Mask Punks
#
# Price
#
# Tokenized Pixels
#
# Price
#
# Gorillas World (Free
#
# ,
#
# 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Pretty Apes Club
#
# Mask Punks #Promo
#
# + 0.0004
#
# 8-Bit Donald Trump
#
# + 0.0005
#
# Airdrop)
#
# Last
#
# + 0.0004
#
# Last
#
# + 0.0004
#
# (airdrop)
#
# Last
#
# + 0.0004
#
# Los
#
# 0.001
#
# 19
#
# 30
#
# 7
#
# 116
#
# 16
#
# x
#
# Ys
#
# Hy
#
# y
#
# 7
#
# fi
#
# Se
#
# *
#
# =
#
# Lag
#
# >
#
# aN
#
# iL
#
# of
#
# ©)
#
# ¢ E
#
# gs
#
# A
#
# O
#
# ae
#
# —0)
#
# >
#
# 4
#
# SS
#
# A
#
# &
#
# f
#
# )
#
# C
#
# cd
#
# —
#
# |
#
# Ve
#
# \y
#
# 4G
#
# a
#
# A
#
# Qe
#
# Lard
#
# D
#
# a
#
# |
#
# Ra
#
# Party Apes Club
#
# Price
#
# Crytho Punks
#
# Price
#
# Scary Ghosts Club
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Angry Apes Collecti..
#
# Price
#
# Catland Metaverse
#
# Party Apes Club (Free
#
# 0.0004
#
# rytho Punks #0000
#
# + 0.0005
#
# Scary Ghosts (Airdrop,
#
# + 0.0004
#
# + 0.0005
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Airdrop)
#
# Last
#
# + 0.0004
#
# Lost
#
# + 0.0005
#
# mint chance 5%)
#
# Last
#
# + 0.0004
#
# Airdrop
#
# Lost
#
# + 0.0005
#
# Airdrop)
#
# Last
#
# + 0.0004
#
# 70
#
# 19
#
# 16
#
# 70
#
# 38
#
# x
#
# a
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_12_17.csv
# saving file as current_screen.png
# Rye
#
# LOLA
#
# Nae
#
# 7
#
# < |
#
# UR
#
# Aad
#
# 1 Og
#
# Cy
#
# eo
#
# _
#
# DIONE?)
#
# 7}
#
# Adopt
#
# a
#
# nd
#
# Me! &
#
# a
#
# Sc
#
# TY
#
# Gorillas World
#
# Price
#
# Price
#
# Last 40,0005,
#
# ‘The Mask Punks
#
# Price
#
# Tokenized Pixels
#
# Price
#
# Meowing Cat
#
# Pretty Apes Club
#
# Gorillas World (Free
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Pretty Apes Club
#
# Mask Punks #Promo
#
# + 0.0004
#
# 8-Bit Donald Trump
#
# + 0.0005
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (airdrop)
#
# Last 4 0.0004
#
# Last + 0.001
#
# %
#
# Ow
#
# 920
#
# Ov
#
# a
#
# O16
#
# O16
#
# ry
#
# ae)
#
# ZZ
#
# ——,
#
# i=
#
# é
#
# e
#
# Soot
#
# et
#
# LL
#
# 2
#
# Cp)
#
# S&S
#
# _
#
# O
#
# ¢
#
# Gg.
#
# ee
#
# WC
#
# ans
#
# =
#
# 32
#
# a
#
# ae,
#
# al
#
# »
#
# I
#
# y,
#
# (i)
#
# Sy
#
# \\
#
# OW
#
# w'
#
# f(
#
# aN
#
# fs
#
# cA
#
# >
#
# Party Apes Club
#
# Price
#
# crytho Punks
#
# Price
#
# Scary Ghosts Club
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Angry Apes Collecti...
#
# Price
#
# Catland Metaverse
#
# Party Apes Club (Free
#
# + 0.0004
#
# rytho Punks #0000
#
# + 0.0005
#
# Scary Ghosts (Airdrop,
#
# + 0.0004
#
# + 0.0005
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 40,0005,
#
# mint chance 5%)
#
# Last 4 0.0004
#
# Airdrop
#
# Last 40,0005,
#
# Airdrop)
#
# Last 4 0.0004
#
# On
#
# Ow
#
# O16
#
# On
#
# Ox
#
# Ce)
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_12_39.csv
# saving file as current_screen.png
# AX AY,
#
# Rye
#
# Nae
#
# ios
#
# < |
#
# oa
#
# \<G
#
# ‘Cy
#
# oad
#
# Ado)
#
# q
#
# iN
#
# nd
#
# a
#
# Sc
#
# v
#
# TY
#
# Gorillas World
#
# Price
#
# Price
#
# Last 40,0005,
#
# ‘The Mask Punks
#
# Price
#
# Tokenized Pixels
#
# Price
#
# Meowing Cat
#
# Pretty Apes Club
#
# Gorillas World (Free
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Pretty Apes Club
#
# Mask Punks #Promo
#
# + 0.0004
#
# 8-Bit Donald Trump
#
# + 0.0005
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (airdrop)
#
# Last 4 0.0004
#
# Last + 0.001
#
# Ow
#
# 920
#
# Ov
#
# O16
#
# O16
#
# ,
#
# ry
#
# aN
#
# ri
#
# Lid
#
# SVs
#
# é
#
# e
#
# Soot
#
# R
#
# Aa
#
# @&
#
# LL
#
# 2
#
# wi A
#
# Gg.
#
# Db
#
# WC
#
# Td
#
# ead
#
# eT
#
# \
#
# Br
#
# y,
#
# Vi
#
# ~
#
# MW)
#
# i \
#
# @Nly: Ws |
#
# Party Apes Club
#
# Price
#
# crytho Punks
#
# Price
#
# Scary Ghosts Club
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Angry Apes Collecti...
#
# Price
#
# Catland Metaverse
#
# Party Apes Club (Free
#
# + 0.0004
#
# rytho Punks #0000
#
# + 0.0005
#
# Scary Ghosts (Airdrop,
#
# + 0.0004
#
# + 0.0005
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 40,0005,
#
# mint chance 5%)
#
# Last 4 0.0004
#
# Airdrop
#
# Last 40,0005,
#
# Airdrop)
#
# Last 4 0.0004
#
# On
#
# Ow
#
# O16
#
# On
#
# Ox
#
# GSS
#
# a
#
# a
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_13_02.csv
# saving file as current_screen.png
# —S a ae
#
# corse TT
#
# —
#
# <5
#
# ee
#
# f
#
# Ki
#
# ee er st
#
# Se
#
# Ee
#
# iS
#
# ——S—_
#
# SS
#
# —— a
#
# =
#
# =
#
# —__=_-
#
# ———<——-_
#
# a
#
# ee ee
#
# ee Se
#
# ae SE
#
# — ae
#
# a
#
# at bs
#
# Treasure Mystery 8.
#
# Last 40.58
#
# Crypto Skull Punk
#
# Price
#
# Party Apes Club
#
# Price
#
# Art Blocks Curated
#
# Last ¢ 3.9
#
# Tigers Deluxe Club
#
# Price
#
# ‘Treasure Mystery Box#57
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Edifice #802
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Last
#
# + 0.0004
#
# Airdrop)
#
# Last
#
# + 0.0004
#
# (Mint chance 5%)
#
# Last
#
# + 0.0004
#
# 4a
#
# 70
#
# ee
#
# “i
#
# a ot
#
# y
#
# f
#
# T=
#
# ©
#
# ae
#
# il
#
# X
#
# om
#
# Pan
#
# Ae
#
# LS
#
# {a
#
# ty
#
# Sa
#
# oI
#
# aa
#
# 6
#
# ry
#
# w
#
# | \
#
# NX
#
# Surreal Man
#
# Price
#
# CatLand Metaverse
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Ghoteeno
#
# Price
#
# Bebop Multiverse
#
# Surreal Man #000
#
# + 0.0004
#
# Catland Metaverse
#
# + 0.0005
#
# Mask Punks #Promo
#
# + 0.0004
#
# Bebop Multiverse
#
# + 0.0005
#
# Ghoteeno #0000
#
# + 0.0004
#
# Promotion
#
# Last
#
# + 0.0004
#
# Airdrop
#
# Lost
#
# + 0.0005
#
# Last
#
# + 0.0004
#
# Lost
#
# + 0.0005
#
# Last
#
# + 0.0004
#
# 56
#
# 70
#
# 116
#
# EE Ta:
#
# e
#
# a
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_13_28.csv
# saving file as current_screen.png
# SS
#
# — a
#
# ——
#
# WD
#
# y
#
# “ae
#
# om
#
# mi
#
# ee mee
#
# DN
#
# Ny
#
# a
#
# Se
#
# —— or 5
#
# A
#
# a
#
# :
#
# —_-——
#
# i
#
# yr
#
# SS
#
# Es]
#
# —— a
#
# =
#
# a
#
# =
#
# a
#
# —<—-_ os
#
# ——_=-
#
# os
#
# —
#
# SS a
#
# oe
#
# eS
#
# cD
#
# — a
#
# 2
#
# PAK
#
# =
#
# w'
#
# f(
#
# aN
#
# Lost
#
# +058
#
# Price
#
# Price
#
# Last ¢ 3.9
#
# Price
#
# ‘Treasure Mystery B..
#
# crypto Skull Punk
#
# Party Apes Club
#
# Art Blocks Curated @
#
# Tigers Deluxe Club
#
# ‘Treasure Mystery Box#57
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Edifice #802
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# e
#
# 92
#
# Ou
#
# On
#
# 92
#
# Vs
#
# i
#
# i
#
# KL \)
#
# WV
#
# a
#
# ee
#
# he
#
# pew
#
# Y
#
# YP
#
# OT)
#
# ‘Oo
#
# CN Z
#
# |
#
# ©
#
# iy
#
# 4
#
# A
#
# 1D 4
#
# oe
#
# ys
#
# a
#
# Ay
#
# nd
#
# a
#
# aa
#
# —
#
# TY
#
# M|
#
# Surreal Man
#
# Price
#
# CatLand Metaverse
#
# Price
#
# ‘The Mask Punks
#
# Price
#
# Bebop Multiverse
#
# Price
#
# Ghoteeno
#
# Price
#
# Surreal Man #000
#
# Catland Metaverse
#
# Mask Punks #Promo
#
# Ghoteeno #0000
#
# + 0.0004
#
# + 0.0005
#
# + 0.0004
#
# Bebop Multiverse
#
# + 0.0005
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Promotion
#
# Last 40,0005,
#
# Last 4 0.0004
#
# O56
#
# e
#
# %
#
# On
#
# 4
#
# O16
#
# 92
#
# 94
#
# EE Ta:
#
# qi
#
# |
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_13_50.csv
# saving file as current_screen.png
# Se
#
# — a
#
# ys
#
# ee Se
#
# ——
#
# y
#
# “ae
#
# (a
#
# AB
#
# \"
#
# ee mee
#
# Wa
#
# No
#
# uss
#
# MEE:
#
# Se
#
# —— or 5
#
# A
#
# r
#
# —_-——
#
# i!
#
# a
#
# = —
#
# =
#
# a ee
#
# =e
#
# a
#
# —<—-_ os
#
# —__=_-
#
# SS a
#
# oe
#
# om
#
# eS
#
# — a
#
# 2
#
# Pal
#
# =~
#
# a
#
# a
#
# Last
#
# + 0.58
#
# Price
#
# Price
#
# Last ¢ 3.9
#
# Price
#
# Treasure Mystery 8.
#
# crypto Skull Punk
#
# Party Apes Club
#
# Art Blocks Curated @
#
# Tigers Deluxe Club
#
# ‘Treasure Mystery Box#57
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Edifice #802
#
# Tigers Deluxe Airdrop
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# (Mint chance 5%)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# 92
#
# Ou
#
# On
#
# 92
#
# Vs
#
# i
#
# KZ
#
# vais!
#
# {\
#
# SN
#
# i
#
# wh
#
# tf
#
# De
#
# ©
#
# A
#
# q
#
# Ah
#
# he
#
# CNG
#
# Ct
#
# ot
#
# 4
#
# A
#
# xR
#
# ==
#
# a
#
# a
#
# on
#
# —
#
# ap
#
# Wi
#
# iy
#
# hy
#
# MI
#
# Surreal Man
#
# Price
#
# CatLand Metaverse
#
# Price
#
# The Mask Punks
#
# Price
#
# Bebop Multiverse
#
# Price
#
# Ghoteeno
#
# Price
#
# Surreal Man #000
#
# Catland Metaverse
#
# Mask Punks #Promo
#
# Ghoteeno #0000
#
# + 0.0004
#
# + 0.0005
#
# + 0.0004
#
# Bebop Multiverse
#
# + 0.0005
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Promotion
#
# Last 40,0005,
#
# Last 4 0.0004
#
# e
#
# %
#
# O56
#
# e
#
# %
#
# On
#
# 8
#
# O16
#
# %
#
# 92
#
# %
#
# 94
#
# EE Ta:
#
# |
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_14_13.csv
# saving file as current_screen.png
# e
#
# Rye
#
# a
#
# 4 ™S
#
# el
#
# _
#
# 6S)
#
# ad
#
# {
#
# Q
#
# q
#
# Adopt
#
# cS
#
# Me! &
#
# a
#
# Pei st A
#
# oP
#
# yy
#
# Price
#
# Price
#
# Price
#
# Last 40,0005,
#
# Last $ 015
#
# Party Apes Club
#
# Meowing Cat
#
# Young Ape Boat Club
#
# Pretty Apes Club
#
# Sipherian Flash
#
# Party Apes Club (Free
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Young Ape Boat Club
#
# + 0.0005
#
# Pretty Apes Club
#
# 202
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Free Airdrop)
#
# Last 40,0005,
#
# (airdrop)
#
# On
#
# 920
#
# O16
#
# Ov
#
# 91
#
# —
#
# on
#
# i
#
# i
#
# KL \)
#
# age
#
# WV
#
# Bi
#
# TR
#
# a
#
# ial
#
# pew
#
# Ki
#
# aa
#
# ss
#
# nN
#
# ie
#
# 5
#
# OT)
#
# ‘
#
# fs
#
# ee
#
# ca
#
# S—
#
# ae]
#
# e |
#
# A
#
# i
#
# 4
#
# =~
#
# ‘4
#
# nd
#
# J
#
# =
#
# a
#
# ne
#
# TY
#
# —
#
# ‘The Mask Punks
#
# Price
#
# Bored Fatty
#
# Price
#
# Gorillas World
#
# Price
#
# Surreal Man
#
# Price
#
# The crypto zombies
#
# Price
#
# Mask Punks #Promo
#
# Surreal Man #000
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Gorillas World (Free
#
# + 0.0004
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 40,0005,
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# 4
#
# O16
#
# 9 106
#
# Ow
#
# O56
#
# O56
#
# Ee ae
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_14_36.csv
# saving file as current_screen.png
# \Se
#
# Rye
#
# ——_
#
# “SS
#
# |
#
# Ce
#
# \—
#
# _—
#
# ——
#
# =~
#
# "
#
# |
#
# )
#
# q
#
# Adopt
#
# ; Me! &
#
# ete
#
# “
#
# Zs
#
# oe
#
# Price
#
# Price
#
# Price
#
# Last 40,0005,
#
# Last 4 015
#
# Party Apes Club
#
# Meowing Cat
#
# Young Ape Boat Club
#
# Pretty Apes Club
#
# Sipherian Flash
#
# Party Apes Club (Free
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Young Ape Boat Club
#
# + 0.0005
#
# Pretty Apes Club
#
# 292,
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Free Airdrop)
#
# Last 40,0005,
#
# (airdrop)
#
# %
#
# %
#
# %
#
# %
#
# On
#
# 920
#
# O16
#
# Ov
#
# 91
#
# a
#
# 7 \
#
# NE
#
# AV
#
# ip
#
# TR
#
# Set
#
# De
#
# ny
#
# i
#
# i‘
#
# »
#
# ie
#
# ee
#
# q
#
# she
#
# ca
#
# a
#
# és
#
# ae]
#
# 4
#
# if
#
# =~
#
# ==
#
# ~~)
#
# a
#
# nd
#
# J
#
# a
#
# ne
#
# ap
#
# vy
#
# The Mask Punks
#
# Price
#
# Bored Fatty
#
# Price
#
# Gorillas World
#
# Price
#
# Surreal Man
#
# Price
#
# The crypto zombies
#
# Price
#
# Mask Punks #Promo
#
# Surreal Man #000
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Gorillas World (Free
#
# + 0.0004
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 40,0005,
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# 8
#
# O16
#
# e
#
# %
#
# 9 106
#
# %
#
# Ow
#
# %
#
# O56
#
# e
#
# %
#
# O56
#
# Ee ae
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_14_59.csv
# saving file as current_screen.png
# \Se
#
# Rye
#
# ——_
#
# ww
#
# |
#
# ~)
#
# Ce
#
# \—
#
# — 3
#
# ——
#
# =~
#
# "
#
# |
#
# )
#
# q
#
# Adopt
#
# ; Me! &
#
# ete
#
# “
#
# Zs
#
# oe
#
# Price
#
# Price
#
# Price
#
# Last 40,0005,
#
# Last 4 015
#
# Party Apes Club
#
# Meowing Cat
#
# Young Ape Boat Club
#
# Pretty Apes Club
#
# Sipherian Flash
#
# Party Apes Club (Free
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Young Ape Boat Club
#
# + 0.0005
#
# Pretty Apes Club
#
# 292,
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Free Airdrop)
#
# Last 40,0005,
#
# (airdrop)
#
# %
#
# %
#
# %
#
# %
#
# On
#
# 920
#
# O16
#
# Ov
#
# 91
#
# a
#
# 7 \
#
# NE
#
# AV
#
# ip
#
# TR
#
# Set
#
# De
#
# ny
#
# i
#
# i‘
#
# »
#
# ~~
#
# ie
#
# AVA
#
# q
#
# she
#
# a
#
# mh
#
# a
#
# YG,
#
# és
#
# y
#
# or)
#
# "
#
# 4
#
# if
#
# a
#
# x
#
# fy
#
# ==
#
# D)
#
# 7
#
# a
#
# nd
#
# a
#
# ne
#
# UG
#
# Z,)
#
# ap
#
# vy
#
# La
#
# ey 2)
#
# ae
#
# The Mask Punks
#
# Price
#
# Bored Fatty
#
# Price
#
# Gorillas World
#
# Price
#
# Surreal Man
#
# Price
#
# The crypto zombies
#
# Price
#
# Mask Punks #Promo
#
# Surreal Man #000
#
# + 0.0004
#
# Bored Fatty #000
#
# + 0.0005
#
# Gorillas World (Free
#
# + 0.0004
#
# + 0.0004
#
# The crypto zombies
#
# + 0.0004
#
# Last 4 0.0004
#
# Last 40,0005,
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# #0000
#
# Last 4 0.0004
#
# 8
#
# O16
#
# e
#
# %
#
# 9 106
#
# %
#
# Ow
#
# %
#
# O56
#
# e
#
# %
#
# O56
#
# Ee ae
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_15_23.csv
# saving file as current_screen.png
# rf
#
# y
#
# Y/)
#
# Ae
#
# f
#
# )
#
# as
#
# es
#
# ae
#
# PS
#
# =
#
# aS
#
# Sy)
#
# ees |
#
# The Sculptured Apes
#
# Price
#
# FatApesclub
#
# Price
#
# Bored Fatty
#
# Price
#
# MutantApesClub
#
# Price
#
# Baby Apes City
#
# Price
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Fat Apes Club Airdrop
#
# + 0.0005
#
# Bored Fatty #000
#
# + 0.0005
#
# Mutant Apes Club (FREE
#
# + 0.0005
#
# Baby Apes City (Free
#
# + 0.0005
#
# Airdrop
#
# Last
#
# + 0.0004
#
# Lost
#
# + 0.0005
#
# Lost
#
# + 0.0005
#
# DROP)
#
# Lost
#
# + 0.0005
#
# Airdrop)
#
# Lost
#
# + 0.0005
#
# 98
#
# n
#
# 106
#
# 67
#
# n
#
# z
#
# 2
#
# Ni
#
# ry
#
# eS
#
# my. 4
#
# c
#
# Hel
#
# Ai,
#
# w
#
# An)
#
# m
#
# x
#
# rN
#
# =
#
# =— )
#
# Lls\
#
# ?
#
# i
#
# a
#
# "
#
# Adopt
#
# jou
#
# th
#
# Me
#
# o
#
# ns
#
# )
#
# [bg
#
# mf
#
# bos
#
# a!
#
# Party Apes Club
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Ghoteeno
#
# Price
#
# Meowing Cat
#
# Price
#
# Young Ape Boat Club
#
# Price
#
# Catland Metaverse
#
# Ghoteeno #0000
#
# Party Apes Club (Free
#
# + 0.0004
#
# + 0.0005
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Young Ape Boat Club
#
# + 0.0005
#
# Airdrop)
#
# Last
#
# + 0.0004
#
# Airdrop
#
# Lost
#
# + 0.0005
#
# Last
#
# + 0.0004
#
# Last
#
# + 0.0004
#
# (Free Airdrop)
#
# Lost
#
# + 0.0005
#
# 70
#
# 69
#
# 30
#
# 16
#
# a
#
# Se ee |
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_15_50.csv
# saving file as current_screen.png
# \
#
# IQ
#
# = Je)
#
# 1
#
# <
#
# Us
#
# iD
#
# NG
#
# Na
#
# aS
#
# y
#
# SAX
#
# ys
#
# x
#
# A
#
# ht
#
# aad)
#
# \
#
# SS
#
# 2)
#
# bi
#
# SS
#
# Price
#
# Price
#
# Price
#
# Price
#
# Price
#
# The Sculptured Apes
#
# FatApesclub
#
# Bored Fatty
#
# MutantApesClub
#
# Baby Apes City
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Fat Apes Club Airdrop
#
# + 0.0005
#
# Bored Fatty #000
#
# + 0.0005
#
# Mutant Apes Club (FREE
#
# + 0.0005
#
# Baby Apes City (Free
#
# + 0.0005
#
# Airdrop
#
# Last 4 0.0004
#
# Last 4 0.0005
#
# Last 4 0.0005
#
# DROP)
#
# Last 4 0.0005
#
# Airdrop)
#
# Last 4 0.0005
#
# %
#
# %
#
# %
#
# %
#
# %
#
# O98
#
# On
#
# 9 106
#
# Qe
#
# On
#
# K
#
# ya
#
# C\ Lf
#
# SS),
#
# aN
#
# oar 0
#
# a7
#
# Aas
#
# _
#
# cD
#
# wy
#
# jw)
#
# Aes
#
# ia
#
# is
#
# ——s
#
# 2
#
# ned
#
# we
#
# 3
#
# es
#
# Cx
#
# Party Apes Club
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Ghoteeno
#
# Price
#
# Meowing Cat
#
# Price
#
# Young Ape Boat Club
#
# Price
#
# Catland Metaverse
#
# Ghoteeno #0000
#
# Party Apes Club (Free
#
# + 0.0004
#
# + 0.0005
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# Young Ape Boat Club
#
# + 0.0005
#
# Airdrop)
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# (Free Airdrop)
#
# Last 4 0.0005
#
# On
#
# QO 6
#
# 94
#
# 920
#
# O16
#
# a aa os cao |
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_16_12.csv
# saving file as current_screen.png
# ae
#
# - |
#
# si
#
# ) s>z
#
# Y
#
# a
#
# 7
#
# i
#
# yp
#
# Y
#
# ws
#
# y
#
# |i
#
# Se,
#
# =
#
# Ss
#
# ip
#
# i‘
#
# —
#
# Se
#
# rae oS
#
# s
#
# cS
#
# ¢
#
# 3
#
# vr
#
# es
#
# mt
#
# Hh
#
# Surreal Man
#
# Price
#
# Price
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Price
#
# The Sculptured Apes
#
# Angry Apes Collecti..
#
# Party Apes Club
#
# Surreal Man #000
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Catland Metaverse
#
# + 0.0005
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0005
#
# Airdrop)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# %
#
# O56
#
# O98
#
# Ox
#
# QO 6
#
# On
#
# \
#
# \\
#
# rf
#
# me
#
# ~
#
# x
#
# Ie
#
# i
#
# O
#
# e)
#
# =
#
# ,
#
# S
#
# ——~
#
# vias
#
# ?
#
# 4
#
# v
#
# iy
#
# Wy
#
# i.
#
# vA
#
# .
#
# ea
#
# —— ~~
#
# I
#
# Pt
#
# bs
#
# Go
#
# ie
#
# LH
#
# h..
#
# = 0.
#
# The crypto zombies
#
# Price
#
# Roaring Leaders
#
# Lost 4 one
#
# crypto Skull Punk
#
# Price
#
# Elegant Apes Club
#
# Price
#
# Robotono
#
# Price
#
# Robotono #0000
#
# The crypto zombies
#
# + 0.0004
#
# Roaring Leader #5180
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# + 0.0004
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# O56
#
# 92
#
# Ou
#
# Oe
#
# Or
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_16_36.csv
# saving file as current_screen.png
# - |
#
# ) s>z
#
# Y
#
# a
#
# 7
#
# i
#
# yp
#
# Y
#
# ws
#
# y
#
# |i
#
# Se,
#
# =
#
# Ss
#
# ip
#
# i‘
#
# —
#
# Se
#
# rae oS
#
# s
#
# cS
#
# ¢
#
# 3
#
# vr
#
# es
#
# mt
#
# Hh
#
# Surreal Man
#
# Price
#
# Price
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Price
#
# The Sculptured Apes
#
# Angry Apes Collecti..
#
# Party Apes Club
#
# Surreal Man #000
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Catland Metaverse
#
# + 0.0005
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0005
#
# Airdrop)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# %
#
# O56
#
# O98
#
# Ox
#
# QO 6
#
# On
#
# rf
#
# me
#
# ~
#
# x
#
# Ie
#
# i
#
# O
#
# a
#
# =
#
# ,
#
# a
#
# ——~
#
# vias
#
# 4
#
# v
#
# iy
#
# Wy
#
# i.
#
# vA
#
# So
#
# ea
#
# —— ~~
#
# I
#
# Pt
#
# if
#
# Go
#
# hy
#
# oy)
#
# LH
#
# h..
#
# = 0.
#
# The crypto zombies
#
# Price
#
# Roaring Leaders
#
# Lost ¢ 0.9
#
# crypto Skull Punk
#
# Price
#
# Elegant Apes Club
#
# Price
#
# Robotono
#
# Price
#
# Robotono #0000
#
# The crypto zombies
#
# + 0.0004
#
# Roaring Leader #5180
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# + 0.0004
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# O56
#
# 92
#
# Ou
#
# Oe
#
# Or
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_17_00.csv
# saving file as current_screen.png
# - |
#
# ) s>z
#
# Y
#
# a
#
# 7
#
# i
#
# yp
#
# Y
#
# ws
#
# y
#
# |i
#
# Se,
#
# =
#
# Ss
#
# ip
#
# i‘
#
# —
#
# Se
#
# rae oS
#
# s
#
# cS
#
# ¢
#
# 3
#
# vr
#
# es
#
# mt
#
# Hh
#
# Surreal Man
#
# Price
#
# Price
#
# Price
#
# CatLand Metaverse
#
# Price
#
# Price
#
# The Sculptured Apes
#
# Angry Apes Collecti..
#
# Party Apes Club
#
# Surreal Man #000
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Catland Metaverse
#
# + 0.0005
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0005
#
# Airdrop)
#
# Last 4 0.0004
#
# %
#
# %
#
# %
#
# %
#
# %
#
# O56
#
# O98
#
# Ox
#
# QO 6
#
# On
#
# rf
#
# me
#
# ~
#
# x
#
# Ie
#
# i
#
# O
#
# a
#
# =
#
# ,
#
# a
#
# ——~
#
# vias
#
# 4
#
# v
#
# iy
#
# Wy
#
# i.
#
# vA
#
# So
#
# ea
#
# —— ~~
#
# I
#
# Pt
#
# if
#
# Go
#
# hy
#
# oy)
#
# LH
#
# h..
#
# = 0.
#
# The crypto zombies
#
# Price
#
# Roaring Leaders
#
# Lost ¢ 0.9
#
# crypto Skull Punk
#
# Price
#
# Elegant Apes Club
#
# Price
#
# Robotono
#
# Price
#
# Robotono #0000
#
# The crypto zombies
#
# + 0.0004
#
# Roaring Leader #5180
#
# Crypto Skull Punk #0000
#
# + 0.0004
#
# Elegant Apes Club (Free
#
# + 0.0004
#
# + 0.0004
#
# #0000
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# O56
#
# 92
#
# Ou
#
# Oe
#
# Or
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_17_24.csv
# saving file as current_screen.png
# Co
#
# Nae
#
# U Pes
#
# yi!
#
# B
#
# x
#
# ST ae
#
# YW)
#
# ~
#
# a
#
# NS
#
# ny)
#
# recs)
#
# I
#
# eo
#
# =
#
# c
#
# -
#
# mn
#
# )
#
# i
#
# a
#
# x
#
# WN
#
# 4
#
# |
#
# a
#
# yes
#
# {|
#
# ZA
#
# Sc
#
# TY
#
# Cre
#
# Price
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Price
#
# Bored Fatty
#
# Crypto Freaks World
#
# Scary Ghosts Club
#
# Party Apes Club
#
# Bored Fatty #000
#
# + 0.0005
#
# crypto Freak #0000
#
# + 0.0004
#
# Mask Punks #Promo
#
# + 0.0004
#
# Scary Ghosts (Airdrop,
#
# + 0.0004
#
# Party Apes Club (Free
#
# + 0.0004
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# mint chance 5%)
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# e
#
# %
#
# 9 106
#
# 9 207
#
# a
#
# O16
#
# O16
#
# On
#
# IS
#
# SI
#
# Zi
#
# S
#
# Cs.
#
# Bigs”
#
# (554
#
# sas
#
# }
#
# Za
#
# Pe
#
# =
#
# —
#
# =Z
#
# \
#
# ee ey
#
# eee
#
# ne
#
# —
#
# E
#
# sr
#
# —=|
#
# q
#
# Adopt
#
# ==
#
# Z=
#
# ==
#
# Be
#
# 4
#
# ; Me! &
#
# —
#
# PA oe
#
# 205
#
# a
#
# Pretty Apes Club
#
# Last 40,0005,
#
# crytho Punks
#
# Price
#
# Ghoteeno
#
# Price
#
# Meowing Cat
#
# Price
#
# Art Blocks Curated @
#
# Best Offer
#
# Ghoteeno #0000
#
# Edifice #274
#
# Pretty Apes Club
#
# rytho Punks #0000
#
# + 0.0005
#
# + 0.0004
#
# Meowing Cat #000
#
# + 0.0004
#
# 0.5
#
# (airdrop)
#
# Last 40,0005,
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Lost 4 3.498
#
# Ov
#
# Ow
#
# e
#
# %
#
# 94
#
# 920
#
# On
#
# _ a a
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_17_47.csv
# saving file as current_screen.png
# oT
#
# i
#
# iA
#
# ENT
#
# Nae
#
# f
#
# wa
#
# a
#
# mn
#
# aul
#
# WC
#
# ‘
#
# a
#
# —
#
# -
#
# eo
#
# a
#
# y,
#
# ms
#
# <a
#
# Sc
#
# TY
#
# Ns
#
# Naf
#
# a
#
# Price
#
# Price
#
# The Mask Punks
#
# Price
#
# Price
#
# Price
#
# Bored Fatty
#
# Crypto Freaks World
#
# Scary Ghosts Club
#
# Party Apes Club
#
# Bored Fatty #000
#
# + 0.0005
#
# crypto Freak #0000
#
# + 0.0004
#
# Mask Punks #Promo
#
# ...
#
# Bored Cat #2133
#
# Mutant Apes Club (FREE
#
# + 0.0005
#
# + 0.0004
#
# ‘The Sculptured Apes
#
# + 0.0004
#
# Strange Horses
#
# + 0.0005
#
# + 0.0004
#
# DROP}
#
# Last 4 0.0005
#
# Last 4 0.0004
#
# Airdrop
#
# Last 4 0.0004
#
# Promotion Airdrop
#
# Last 4 0.0005
#
# Last + 0.0009
#
# e
#
# %
#
# Qe
#
# e
#
# %
#
# O56
#
# e
#
# %
#
# O98
#
# e
#
# %
#
# 920
#
# e
#
# %
#
# 93
#
# [|
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_26_54.csv
# saving file as current_screen.png
# c
#
# ER
#
# ~~
#
# \
#
# y
#
# iv
#
# =
#
# Gia
#
# 7
#
# co /
#
# \
#
# a’
#
# ONE
#
# au
#
# e
#
# )
#
# Laos
#
# a
#
# ~~
#
# i
#
# a
#
# a
#
# r
#
# wv
#
# py
#
# es)
#
# \ (Ener ones
#
# Party Ape | Billionair..
#
# Best Offer
#
# Chris Plascik
#
# Price
#
# Bored Fatty
#
# Price
#
# Art Blocks Curated @
#
# Best Offer
#
# LOSTPOETS @
#
# Best Offer
#
# APE #00796
#
# > 0.4805
#
# Right Click Save Yourself
#
# 42
#
# Bored Fatty #000
#
# + 0.0005
#
# Edifice #518
#
# $25
#
# Poet #22454
#
# + 0.302
#
# Last ¢ 0.92
#
# vl
#
# Last ¢ 0.0888
#
# Last 40,0005,
#
# Lost #325
#
# Lost 4 0.798
#
# 92
#
# e
#
# %
#
# ivity
#
# 9 106
#
# 91
#
# 91
#
# at
#
# <7
#
# oe
#
# =
#
# we
#
# &
#
# Ss
#
# -
#
# 7
#
# AG
#
# ow
#
# 7
#
# oy
#
# #
#
# ert
#
# wate
#
# ca
#
# Ws
#
# Py
#
# (cp
#
# =
#
# A
#
# ca
#
# ath 4
#
# ih
#
# J
#
# iy
#
# ))
#
# Sipherian Flash
#
# Best Offer
#
# Wicked Ape Bone Cl... @
#
# Best Offer
#
# Robotono
#
# Price
#
# Surreal Man
#
# Price
#
# Angry Apes Collecti...
#
# Price
#
# 292,
#
# Robotono #0000
#
# Surreal Man #000
#
# + 0.12
#
# Wicked Ape #3674
#
# + 0.065
#
# + 0.0004
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Lost ¢ 0155
#
# Last ¢ 0.11
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# e
#
# 91
#
# 94
#
# Or
#
# %
#
# O56
#
# Ox
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_27_16.csv
# saving file as current_screen.png
# &
#
# ER
#
# ~~
#
# \
#
# =
#
# Gia
#
# co /
#
# \
#
# ONE
#
# au
#
# e
#
# i
#
# bh
#
# rN
#
# ff
#
# x
#
# x
#
# Me
#
# ~~
#
# a
#
# °
#
# lt
#
# py
#
# Sone
#
# es)
#
# Seve ney
#
# Party Ape | Billionair..
#
# Best Offer
#
# Chris Plascik
#
# Price
#
# Bored Fatty
#
# Price
#
# Art Blocks Curated @
#
# Best Offer
#
# LOSTPOETS @
#
# Best Offer
#
# APE #00796
#
# > 0.4805
#
# Right Click Save Yourself
#
# 42
#
# Bored Fatty #000
#
# + 0.0005
#
# Edifice #518
#
# $25
#
# Poet #22454
#
# + 0.302
#
# Last ¢ 0.92
#
# vl
#
# Last ¢ 0.0888
#
# Last 40,0005,
#
# Lost #325
#
# Lost 4 0.798
#
# 92
#
# e
#
# %
#
# ivity
#
# 9 106
#
# 91
#
# 91
#
# ees
#
# &
#
# AG
#
# ow
#
# la
#
# >
#
# oy
#
# ert
#
# se
#
# ca
#
# Ws
#
# Py
#
# Et
#
# Ss
#
# (cp
#
# =
#
# A
#
# ca
#
# ath 4
#
# ih
#
# J
#
# Si)
#
# Sipherian Flash
#
# Best Offer
#
# Wicked Ape Bone Cl... @
#
# Best Offer
#
# Robotono
#
# Price
#
# Surreal Man
#
# Price
#
# Angry Apes Collecti...
#
# Price
#
# 202
#
# Robotono #0000
#
# Surreal Man #000
#
# + 0.12
#
# Wicked Ape #3674
#
# + 0.065
#
# + 0.0004
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Lost ¢ 0155
#
# Last ¢ 0.11
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# e
#
# 91
#
# 94
#
# Or
#
# %
#
# O56
#
# Ox
#
# Gls)
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_27_34.csv
# saving file as current_screen.png
# F
#
# &
#
# ER
#
# 2g
#
# \
#
# WS!
#
# yi
#
# Gia
#
# a
#
# ONE
#
# Mi
#
# ))
#
# a
#
# nN
#
# ei
#
# i
#
# oe
#
# a
#
# ra
#
# lt
#
# geTaI}
#
# li
#
# Party Ape | Billionair..
#
# Best Offer
#
# Chris Plascik
#
# Price
#
# Bored Fatty
#
# Price
#
# Art Blocks Curated @
#
# Best Offer
#
# LOSTPOETS @
#
# Best Offer
#
# APE #00796
#
# > 0.4805
#
# Right Click Save Yourself
#
# 42
#
# Bored Fatty #000
#
# + 0.0005
#
# Edifice #518
#
# $25
#
# Poet #22454
#
# + 0.302
#
# Last ¢ 0.92
#
# vl
#
# Last ¢ 0.0888
#
# Last 40,0005,
#
# Lost #325
#
# Lost 4 0.798
#
# 92
#
# ivity
#
# 9 106
#
# 91
#
# 91
#
# a
#
# \
#
# i
#
# as
#
# oan.
#
# v
#
# a
#
# m4
#
# x
#
# ax
#
# ii
#
# SS
#
# se
#
# rs
#
# (cp
#
# =
#
# A
#
# ES
#
# 2
#
# ih
#
# Ah
#
# a
#
# ee
#
# Wi
#
# fy:
#
# Wr
#
# HM
#
# Sipherian Flash
#
# Best Offer
#
# Wicked Ape Bone Cl... @
#
# Best Offer
#
# Robotono
#
# Price
#
# Surreal Man
#
# Price
#
# Angry Apes Collecti...
#
# Price
#
# 202
#
# Robotono #0000
#
# Surreal Man #000
#
# + 0.12
#
# Wicked Ape #3674
#
# + 0.065
#
# + 0.0004
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Lost ¢ 0155
#
# Last ¢ 0.11
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# 91
#
# ivity
#
# Or
#
# O56
#
# Ox
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_27_54.csv
# saving file as current_screen.png
# F
#
# &
#
# ER
#
# 2g
#
# \
#
# WS!
#
# yi
#
# Gia
#
# a
#
# ONE
#
# Mi
#
# ))
#
# a
#
# nN
#
# ei
#
# i
#
# oe
#
# a
#
# ra
#
# lt
#
# geTaI}
#
# li
#
# Party Ape | Billionair..
#
# Best Offer
#
# Chris Plascik
#
# Price
#
# Bored Fatty
#
# Price
#
# Art Blocks Curated @
#
# Best Offer
#
# LOSTPOETS @
#
# Best Offer
#
# APE #00796
#
# > 0.4805
#
# Right Click Save Yourself
#
# 42
#
# Bored Fatty #000
#
# + 0.0005
#
# Edifice #518
#
# $25
#
# Poet #22454
#
# + 0.302
#
# Last ¢ 0.92
#
# vl
#
# Last ¢ 0.0888
#
# Last 40,0005,
#
# Lost #325
#
# Lost 4 0.798
#
# 92
#
# ivity
#
# 9 106
#
# 91
#
# 91
#
# a
#
# S
#
# oan.
#
# v
#
# a
#
# m4
#
# x
#
# ax
#
# ii
#
# SS
#
# se
#
# rs
#
# (cp
#
# =
#
# A
#
# ES
#
# 2
#
# ih
#
# Ah
#
# a
#
# ee
#
# Wi
#
# fy:
#
# Wr
#
# HM
#
# Sipherian Flash
#
# Best Offer
#
# Wicked Ape Bone Cl... @
#
# Best Offer
#
# Robotono
#
# Price
#
# Surreal Man
#
# Price
#
# Angry Apes Collecti...
#
# Price
#
# 202
#
# Robotono #0000
#
# Surreal Man #000
#
# + 0.12
#
# Wicked Ape #3674
#
# + 0.065
#
# + 0.0004
#
# + 0.0004
#
# ‘Angry Apes Club (Free
#
# + 0.0004
#
# Lost ¢ 0155
#
# Last ¢ 0.11
#
# Last 4 0.0004
#
# Last 4 0.0004
#
# Airdrop)
#
# Last 4 0.0004
#
# 91
#
# ivity
#
# Or
#
# O56
#
# Ox
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_28_14.csv
# saving file as current_screen.png
# =
#
# =
#
# i
#
# "A
#
# cuz
#
# Y
#
# iV,
#
# al
#
# W”
#
# \
#
# es
#
# NG
#
# ”7a\
#
# /
#
# 14
#
# a2
#
# fa
#
# CcryptoMories
#
# Best Offer
#
# Mutant Ape Yacht C... &
#
# Best Offer
#
# REMIX! by APE DAO.
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Cryptomories #3106
#
# 4 0.09
#
# 9070
#
# 44
#
# APE DAO REMIX! #1212
#
# 4 0.04
#
# #3770
#
# + 0.8849
#
# ‘#7518
#
# 4 0.8618
#
# Last #014
#
# Last 45
#
# Last $04
#
# Lost #1189
#
# Last ¢ 138
#
# 92
#
# On
#
# 91
#
# on
#
# oa
#
# a
#
# OT
#
# v
#
# eae
#
# y)
#
# é
#
# y—
#
# OY
#
# ne
#
# \
#
# lg
#
# ‘Ca
#
# A
#
# ad
#
# \
#
# 1H
#
# 1
#
# BlockBots by indore
#
# Last $04
#
# The World of Umans @
#
# Last 4 0.33
#
# Dogs of Elon
#
# Lost #0135,
#
# Art Blocks Curated @
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Blockbot #335
#
# uUman #8
#
# #1031
#
# Edifice #75
#
# #7235
#
# 425
#
# 4 0.941
#
# Last 97.5
#
# Lost ¢ 1.098
#
# 98
#
# 92
#
# 92
#
# 91
#
# Vs
#
# e
#
# se
#
# Se
#
# Re a
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_28_35.csv
# saving file as current_screen.png
# =
#
# =
#
# i
#
# "A
#
# cuz
#
# Y
#
# iV,
#
# al
#
# W”
#
# \
#
# es
#
# NG
#
# ”7a\
#
# /
#
# 14
#
# a2
#
# fa
#
# CcryptoMories
#
# Best Offer
#
# Mutant Ape Yacht C... &
#
# Best Offer
#
# REMIX! by APE DAO.
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Cryptomories #3106
#
# 4 0.09
#
# 9070
#
# 44
#
# APE DAO REMIX! #1212
#
# 4 0.04
#
# #3770
#
# + 0.8849
#
# ‘#7518
#
# 4 0.8618
#
# Last #014
#
# Last 45
#
# Last $04
#
# Lost #1189
#
# Last ¢ 138
#
# 92
#
# On
#
# 91
#
# on
#
# oa
#
# a
#
# OT
#
# v
#
# eae
#
# y)
#
# é
#
# y—
#
# OY
#
# ne
#
# \
#
# lg
#
# ‘Ca
#
# A
#
# ad
#
# \
#
# 1H
#
# 1
#
# BlockBots by indore
#
# Last $04
#
# The World of Umans @
#
# Last 4 0.33
#
# Dogs of Elon
#
# Lost #0135,
#
# Art Blocks Curated @
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Blockbot #335
#
# uUman #8
#
# #1031
#
# Edifice #75
#
# #7235
#
# 425
#
# 4 0.941
#
# Last 97.5
#
# Lost ¢ 1.098
#
# 98
#
# 92
#
# 92
#
# 91
#
# Vs
#
# e
#
# se
#
# Se
#
# Re a
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_28_52.csv
# saving file as current_screen.png
# =
#
# =
#
# i
#
# "A
#
# cuz
#
# Y
#
# iV,
#
# al
#
# W”
#
# \
#
# es
#
# NG
#
# ”7a\
#
# /
#
# 14
#
# a2
#
# fa
#
# CcryptoMories
#
# Best Offer
#
# Mutant Ape Yacht C... &
#
# Best Offer
#
# REMIX! by APE DAO.
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Cryptomories #3106
#
# 4 0.09
#
# 9070
#
# 44
#
# APE DAO REMIX! #1212
#
# 4 0.04
#
# #3770
#
# + 0.8849
#
# ‘#7518
#
# 4 0.8618
#
# Last #014
#
# Last 45
#
# Last $04
#
# Lost #1189
#
# Last ¢ 138
#
# 92
#
# On
#
# 91
#
# on
#
# oa
#
# a
#
# OT
#
# v
#
# eae
#
# y)
#
# é
#
# y—
#
# OY
#
# ne
#
# \
#
# lg
#
# ‘Ca
#
# A
#
# ad
#
# \
#
# 1H
#
# 1
#
# BlockBots by indore
#
# Last $04
#
# The World of Umans @
#
# Last 4 0.33
#
# Dogs of Elon
#
# Lost #0135,
#
# Art Blocks Curated @
#
# Best Offer
#
# Lazy Lions &
#
# Best Offer
#
# Blockbot #335
#
# uUman #8
#
# #1031
#
# Edifice #75
#
# #7235
#
# 425
#
# 4 0.941
#
# Last 97.5
#
# Lost ¢ 1.098
#
# 98
#
# 92
#
# 92
#
# 91
#
# Vs
#
# e
#
# se
#
# Se
#
# Re a
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_29_11.csv
# saving file as current_screen.png
# YAKS
#
# <->}
#
# >’
#
# i
#
# \
#
# “i,
#
# \W\
#
# SD
#
# La
#
# A,
#
# 3
#
# a
#
# -
#
# NS
#
# 2
#
# nl
#
# CG
#
# Ss
#
# Sh
#
# we =
#
# care Oa
#
# a
#
# »
#
# Cy
#
# a
#
# Mutant-Gorillas
#
# Lost 4 0.063
#
# Knights of Degen ~ ..
#
# Last 40.05
#
# FLUF World: Thingies
#
# Lost 4 0.1752
#
# The Shakai
#
# Last 401
#
# Secret Society of W.. @
#
# Last 4 0.068
#
# #3846
#
# Knights of Degen #8656
#
# 6453
#
# 336
#
# 2179
#
# 91
#
# Vo
#
# 91
#
# Vo
#
# O58
#
# ki
#
# tx
#
# a”
#
# TLeded
#
# &)
#
# 7
#
# a
#
# »
#
# Jae
#
# ASM AIFA Genesis
#
# Best Offer
#
# Impact Theory Foun...
#
# Best Offer
#
# Art Blocks Curated @
#
# Best Offer
#
# Borpacasso @
#
# Last
#
# $01
#
# Gods Of Rock
#
# Lost 4 0.045
#
# ASM AIFA Genesis #4152
#
# ITFK Heroic 07612
#
# Edifice #197
#
# Gods Of Rock #8266
#
# > 0.2153
#
# + 0.67
#
# b27
#
# Borpacasso 679/250
#
# Last 4 0,399
#
# Last 4 0.65
#
# Lost #32
#
# Vo
#
# Vo
#
# 91
#
# 93
#
# 93
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_29_31.csv
# saving file as current_screen.png
# YAKS
#
# <->}
#
# >’
#
# i
#
# \
#
# “i,
#
# \W\
#
# SD
#
# La
#
# A,
#
# 3
#
# a
#
# -
#
# NS
#
# 2
#
# nl
#
# CG
#
# Ss
#
# Sh
#
# we =
#
# care Oa
#
# a
#
# »
#
# Cy
#
# a
#
# Mutant-Gorillas
#
# Lost 4 0.063
#
# Knights of Degen ~ ..
#
# Last 40.05
#
# FLUF World: Thingies
#
# Lost 4 0.1752
#
# The Shakai
#
# Last 401
#
# Secret Society of W.. @
#
# Last 4 0.068
#
# #3846
#
# Knights of Degen #8656
#
# 6453
#
# 336
#
# 2179
#
# 91
#
# Vo
#
# 91
#
# Vo
#
# O58
#
# ki
#
# tx
#
# a”
#
# TLeded
#
# &)
#
# 7
#
# a
#
# »
#
# Jae
#
# ASM AIFA Genesis
#
# Best Offer
#
# Impact Theory Foun...
#
# Best Offer
#
# Art Blocks Curated @
#
# Best Offer
#
# Borpacasso @
#
# Last
#
# $01
#
# Gods Of Rock
#
# Lost 4 0.045
#
# ASM AIFA Genesis #4152
#
# ITFK Heroic 07612
#
# Edifice #197
#
# Gods Of Rock #8266
#
# > 0.2153
#
# + 0.67
#
# b27
#
# Borpacasso 679/250
#
# Last 4 0,399
#
# Last 4 0.65
#
# Lost #32
#
# Vo
#
# Vo
#
# 91
#
# 93
#
# 93
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_29_47.csv
# saving file as current_screen.png
# YAKS
#
# <->}
#
# >’
#
# i
#
# \
#
# “i,
#
# \W\
#
# SD
#
# La
#
# A,
#
# 3
#
# a
#
# -
#
# NS
#
# 2
#
# nl
#
# CG
#
# Ss
#
# Sh
#
# we =
#
# care Oa
#
# a
#
# »
#
# Cy
#
# a
#
# Mutant-Gorillas
#
# Lost 4 0.063
#
# Knights of Degen ~ ..
#
# Last 40.05
#
# FLUF World: Thingies
#
# Lost 4 0.1752
#
# The Shakai
#
# Last 401
#
# Secret Society of W.. @
#
# Last 4 0.068
#
# #3846
#
# Knights of Degen #8656
#
# 6453
#
# 336
#
# 2179
#
# 91
#
# Vo
#
# 91
#
# Vo
#
# O58
#
# ki
#
# tx
#
# a”
#
# TLeded
#
# &)
#
# 7
#
# a
#
# »
#
# Jae
#
# ASM AIFA Genesis
#
# Best Offer
#
# Impact Theory Foun...
#
# Best Offer
#
# Art Blocks Curated @
#
# Best Offer
#
# Borpacasso @
#
# Last
#
# $01
#
# Gods Of Rock
#
# Lost 4 0.045
#
# ASM AIFA Genesis #4152
#
# ITFK Heroic 07612
#
# Edifice #197
#
# Gods Of Rock #8266
#
# > 0.2153
#
# + 0.67
#
# b27
#
# Borpacasso 679/250
#
# Last 4 0,399
#
# Last 4 0.65
#
# Lost #32
#
# Vo
#
# Vo
#
# 91
#
# 93
#
# 93
#
# Gees
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_30_06.csv
# saving file as current_screen.png
# YAKS
#
# <->}
#
# >’
#
# i
#
# \
#
# “i,
#
# \W\
#
# SD
#
# La
#
# A,
#
# 3
#
# a
#
# -
#
# NS
#
# 2
#
# nl
#
# CG
#
# Ss
#
# Sh
#
# we =
#
# care Oa
#
# a
#
# »
#
# Cy
#
# a
#
# Mutant-Gorillas
#
# Lost 4 0.063
#
# Knights of Degen ~ ..
#
# Last 40.05
#
# FLUF World: Thingies
#
# Lost 4 0.1752
#
# The Shakai
#
# Last 401
#
# Secret Society of W.. @
#
# Last 4 0.068
#
# #3846
#
# Knights of Degen #8656
#
# 6453
#
# 336
#
# 2179
#
# 91
#
# Vo
#
# 91
#
# Vo
#
# O58
#
# ki
#
# tx
#
# a”
#
# TLeded
#
# &)
#
# 7
#
# a
#
# »
#
# Jae
#
# ASM AIFA Genesis
#
# Best Offer
#
# Impact Theory Foun...
#
# Best Offer
#
# Art Blocks Curated @
#
# Best Offer
#
# Borpacasso @
#
# Last
#
# $01
#
# Gods Of Rock
#
# Lost 4 0.045
#
# ASM AIFA Genesis #4152
#
# ITFK Heroic 07612
#
# Edifice #197
#
# Gods Of Rock #8266
#
# > 0.2153
#
# + 0.67
#
# b27
#
# Borpacasso 679/250
#
# Last 4 0,399
#
# Last 4 0.65
#
# Lost #32
#
# Vo
#
# Vo
#
# 91
#
# 93
#
# 93
#
# Gees
#
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_30_25.csv
# saving file as current_screen.png
# Oe
#
# eX -\
#
# \
#
# sn
#
# ee:
#
# eel
#
# ae
#
# Dr)
#
# la
#
# es
#
# My
#
# ae
#
# cw
#
# \
#
# |
#
# ues
#
# ue
#
# tl
#
# pe
#
# |
#
# b
#
# I:
#
# |
#
# _
#
# ==
#
# rt
#
# Wa dn Sec a
#
# oh
#
# Ly
#
# w
#
# Lost 4 0136
#
# THE REAL GOAT SOC.
#
# Art Blocks Curated
#
# Best Offer
#
# Art Blocks Curated
#
# Best Offer
#
# ‘Cosmic Labs
#
# Best Offer
#
# Art Blocks Curated
#
# Best Offer
#
# 7814
#
# Edifice #204
#
# $25
#
# Edifice #224
#
# $25
#
# ‘Cosmic Duck #1982
#
# + 0.05
#
# Edifice #476
#
# $25
#
# Lost #34
#
# Lost 4 3.399
#
# Lost #012
#
# Vo
#
# Vo
#
# 91
#
# Vo
#
# Vo
#
# O o
#
# =e
#
# Ww
#
# .
#
# SS a
#
# PN)
#
# ey
#
# S)
#
# a
#
# bs
#
# ak
#
# ee
#
# Css
#
# 4
#
# Wl
#
# <i
#
# ig,
#
# i
#
# oe
#
# A)
#
# SI
#
# ne
#
# Hae
#
# Ay fe
#
# BAS
#
# eo
#
# WY
#
# \ SN
#
# Ss
#
# {0
#
# S35
#
# Se A
#
# omen
#
# S
#
# Po
#
# A
#
# Dogs Unleashed
#
# Price
#
# Sacred Spiders
#
# Last 4 0.0005
#
# Magic Mushroom Cl...
#
# Price
#
# Fat Ape Club
#
# Last
#
# 0.18
#
# Letters by Vinnie Ha.
#
# Best Offer
#
# #8154
#
# Dog's Unleashed 102
#
# + 0.001
#
# Sacred Spiders #883
#
# Magic Mushroom #5286
#
# 40.12
#
# ‘On The Road Again
#
# > 0.2332
#
# Last + 0.001
#
# Last # 0.065
#
# Lost 4 0.4387
#
# 8
#
# 93
#
# %
#
# Vo
#
# 92
#
# 92
#
# 93
#
# ‘ae Ml
#
# EZ,
#
# &
# exported /Users/apple/Desktop/nft/opensea_scrapings/11_08_2021_20_30_44.csv
# saving file as current_screen.png
# Oe
#
# eX -\
#
# \
#
# sn
#
# ee:
#
# eel
#
# ae
#
# Dr)
#
# la
#
# es
#
# My
#
# ae
#
# cw
#
# \
#
# |
#
# ues
#
# ue
#
# tl
#
# pe
#
# |
#
# b
#
# I:
#
# |
#
# _
#
# ==
#
# rt
#
# Wa dn Sec a
#
# oh
#
# Ly
#
# w
#
# Lost 4 0136
#
# THE REAL GOAT SOC.
#
# Art Blocks Curated
#
# Best Offer
#
# Art Blocks Curated
#
# Best Offer
#
# ‘Cosmic Labs
#
# Best Offer
#
# Art Blocks Curated
#
# Best Offer
#
# 7814
#
# Edifice #204
#
# $25
#
# Edifice #224
#
# $25
#
# ‘Cosmic Duck #1982
#
# + 0.05
#
# Edifice #476
#
# $25
#
# Lost #34
#
# Lost 4 3.399
#
# Lost #012
#
# Vo
#
# Vo
#
# 91
#
# Vo
#
# Vo
#
# O o
#
# =e
#
# Ww
#
# .
#
# SS a
#
# PN)
#
# ey
#
# S)
#
# a
#
# bs
#
# ak
#
# ee
#
# Css
#
# 4
#
# Wl
#
# <i
#
# ig,
#
# i
#
# oe
#
# A)
#
# SI
#
# ne
#
# Hae
#
# Ay fe
#
# BAS
#
# eo
#
# WY
#
# \ SN
#
# Ss
#
# {0
#
# S35
#
# Se A
#
# omen
#
# S
#
# Po
#
# A
#
# Dogs Unleashed
#
# Price
#
# Sacred Spiders
#
# Last 4 0.0005
#
# Magic Mushroom Cl...
#
# Price
#
# Fat Ape Club
#
# Last
#
# 0.18
#
# Letters by Vinnie Ha.
#
# Best Offer
#
# #8154
#
# Dog's Unleashed 102
#
# + 0.001
#
# Sacred Spiders #883
#
# Magic Mushroom #5286
#
# 40.12
#
# ‘On The Road Again
#
# > 0.2332
#
# Last + 0.001
#
# Last # 0.065
#
# Lost 4 0.4387
#
# 8
#
# 93
#
# %
#
# Vo
#
# 92
#
# 92
#
# 93
#
# ‘ae Ml
#
# EZ,
#
# &
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-8549926afc4c> in <module>
#     116         crop_rectangle = (start_x,start_y_pixel, end_x, end_y_pixel)  # left, upper, right, lower)
#     117         cropped_closer = cropped_im.crop(crop_rectangle)
# --> 118         prices.append(pytesseract.image_to_string(cropped_closer))
#     119         start_x += 320
#     120         end_x += 320
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     407     args = [image, 'txt', lang, config, nice, timeout]
#     408
# --> 409     return {
#     410         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     411         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in <lambda>()
#     410         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     411         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 412         Output.STRING: lambda: run_and_get_output(*args),
#     413     }[output_type]()
#     414
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     285         }
#     286
# --> 287         run_tesseract(**kwargs)
#     288         filename = kwargs['output_filename_base'] + extsep + extension
#     289         with open(filename, 'rb') as output_file:
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     259         raise TesseractNotFoundError()
#     260
# --> 261     with timeout_manager(proc, timeout) as error_string:
#     262         if proc.returncode:
#     263             raise TesseractError(proc.returncode, get_errors(error_string))
#
# /usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.9/site-packages/pytesseract/pytesseract.py in timeout_manager(proc, seconds)
#     123     try:
#     124         if not seconds:
# --> 125             yield proc.communicate()[1]
#     126             return
#     127
#
# /usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/subprocess.py in communicate(self, input, timeout)
#    1132
#    1133             try:
# -> 1134                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1135             except KeyboardInterrupt:
#    1136                 # https://bugs.python.org/issue25942
#
# /usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1977                             'failed to raise TimeoutExpired.')
#    1978
# -> 1979                     ready = selector.select(timeout)
#    1980                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1981
#
# /usr/local/Cellar/python@3.9/3.9.7/Frameworks/Python.framework/Versions/3.9/lib/python3.9/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:
