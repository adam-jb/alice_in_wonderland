# %% [markdown]
# Make images of Alices in Wonderland paragraphs. Text from Project Gutenberg.
#
#
# ## To download a font

# %%
import requests
import re
from PIL import Image, ImageDraw, ImageFont
import numpy as np
import matplotlib.pyplot as plt
import math
from swtloc import SWTLocalizer
from swtloc.utils import imgshowN, imgshow

# %%
with open('alice.txt') as f:
    body = f.readlines()
    
# dropping underscores and excess spaces
for_next = [x.replace('\n', '').replace('_', '').replace('  ', '')  for x in body]  

# converting to paragraphs
alice = []
temp_line = ''
for line in for_next:
    if line != "":
        temp_line = temp_line + ' ' + line
    else:
        temp_line = temp_line[1:]
        alice.append(temp_line)
        temp_line = ''

alice[:3]
# Out:
# ['Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, “and what is the use of a book,” thought Alice “without pictures or conversations?”',
#  'So she was considering in her own mind (as well as she could, for the hot day made her feel very sleepy and stupid), whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her.',
# ...

# %%
# text changing and filtering in one
#[x.replace('\n', '').replace('_', '').replace('  ', '')  for x in body if x.replace('\n', '')  != '']

# %%
# numbers as 
number_images = []

for i in range(10):
    
    im = Image.open(r"letter_images/" + str(i) + ".jpg") 
    width, height = im.size
    #im_number = im.resize((math.ceil(im.width/6), math.ceil(im.height/6)), Image.ANTIALIAS)
    im_number = im.resize((90, 140), Image.ANTIALIAS)

    number_images.append(im_number)

# %%
# combine numbers
def make_image_numbers(input_number):
    
    string_number = str(input_number)
    no_of_numbers = len(string_number)
        
    first_number = int(string_number[0])
    im_number = number_images[first_number]
        
    new_image_height = im_number.height
    new_image_width = (im_number.width * no_of_numbers) + (10 * (no_of_numbers-1))

    new_image = Image.new('RGB',(new_image_width, new_image_height), (255,255,255))
    
    new_image.paste(im_number,(0,0))
    
    if no_of_numbers >= 2:
        second_number = int(string_number[1])
        im_number = number_images[second_number]
        new_image.paste(im_number,(im_number.width+10,0))
        
    if no_of_numbers >= 3:
        third_number = int(string_number[2])
        im_number = number_images[third_number]
        new_image.paste(im_number,( (im_number.width+10)*2,0))
    
    return new_image


make_image_numbers(2)
# Out:
# <PIL.Image.Image image mode=RGB size=90x140 at 0x13BDCFDC0>

# %%
alice = [x for x in alice if (len(x) >= 1)]  # dropping blank chapters
len(alice)
# Out:
# 787

# %%
w = 1050 # 100 pixels wide
h = 1050

longest = np.max([len(x) for x in alice])

images_store = []


for image_iter in range(len(alice)):

    text = alice[image_iter]


    # split text into words
    words = text.split(' ')
    

    nchars = len(text)

    ### scaling lines and font sizes
    try:

        if nchars < 300:
            line_count = math.ceil(math.pow(nchars,0.5) / 2)
            line_len = math.ceil(nchars / (line_count))
            font_size = math.ceil(60 / math.pow(line_count,0.5) * 3)

        elif nchars < 600:
            line_count = math.ceil(math.pow(nchars,0.5) / 2)
            line_len = math.ceil(nchars / (line_count))
            font_size = math.ceil(50 / math.pow(line_count,0.5) * 2.6)

        elif nchars < 750:
            line_count = math.ceil(math.pow(nchars,0.5) / 2)
            line_len = math.ceil(nchars / (line_count))
            font_size = math.ceil(42 / math.pow(line_count,0.5) * 2.5)

        else:
            line_count = math.ceil(math.pow(nchars,0.5) / 2)
            line_len = math.ceil(nchars / (line_count))
            font_size = math.ceil(42 / math.pow(line_count,0.5) * 2.5)

    except:
        continue
            
    ####if chars low...
    #font size = bigger
    #line_len = smaller
    #line_count = smaller
    

    # splitting text onto multiple rows
    lines = []
    for i in range(line_count):
        lines.append(text[i*line_len:(i+1)*line_len])
        
        
    
    """
    # moving rest of text to next row
    for i in range(len(line)):
        
        ix = len(line) - i - 1
        if lines[z][ix-1] == ' ':
            
            if z == len(lines):
                lines[z+1] = ''
                
            current = lines[z][:ix]
            rest = lines[z][ix:]
            lines[z+1] = rest + '' + lines[z+1]
            print(current)
            
            break

              
    text_for_img = '\n'.join(lines)
    """

    # adding line breaks
    """
    for z in range(len(lines)):
        
        print(lines[z])
        
        if len(lines[z]) > line_len:
            
            if z == len(lines):  # adding new
                lines[z+1] = ''
                
            spl = lines.split(' ')
            print(spl)
            lines[z] = spl[:-1]
            
            for_next_line = spl[-1]
            lines[z+1] = for_next_line + ' ' + lines[z+1]
            
            print(for_next_line)
            
        
        # 2nd iter in case moving one word isn't enough, then 3rd and 4th just in case
        if len(lines[z]) > line_len: 
            spl = lines.split(' ')
            lines[z] = spl[:-1]
            for_next_line = spl[-1]
            lines[z+1] = for_next_line + ' ' + lines[z+1]
        
        if len(lines[z]) > line_len:
            spl = lines.split(' ')
            lines[z] = spl[:-1]
            for_next_line = spl[-1]
            lines[z+1] = for_next_line + ' ' + lines[z+1]
        
        if len(lines[z]) > line_len:
            spl = lines.split(' ')
            lines[z] = spl[:-1]
            for_next_line = spl[-1]
            lines[z+1] = for_next_line + ' ' + lines[z+1]
        

    text_for_img = '\n'.join(lines)
    
    
    """
    
    for z in range(1,len(lines)):
        for i in range(len(lines[z])):
            if lines[z][i] == ' ':
                prior = lines[z][:i]
                rest = lines[z][i:]
                lines[z-1] = lines[z-1] + prior
                lines[z] = rest[1:]
                break

              
    text_for_img = '\n'.join(lines)
    
    print(lines)
    
    
    """
    # moving word to next line if line is too long
    for z in range(len(lines)):
        if len(lines[z]) > line_len:
            
            if z == len(lines):  # adding new row to populate if moving onto another line and on final line already
                lines[z+1] = ''
                
            print(lines[z])
            
            the_line = lines[z]
            the_line_list = the_line.split(' ')
            for_next_line = the_line_list[-1]
            the_line_list = the_line_list[:-1]
            print(the_line_list)
            lines[z] = ' '.join(the_line_list)
            lines[z+1] = for_next_line + ' ' + lines[z+1]
            
           # print(lines[z])
    """
    

    
    img = Image.new('RGB', (w, h), color='white')
    image_editable  = ImageDraw.Draw(img)

    # IBM Plex Sans
    font = ImageFont.truetype('/Users/apple/Library/Fonts/IBMPlexSans-Medium.ttf', font_size)  # source Arial font from Mac
    draw = ImageDraw.Draw(img)
    draw.text((60, 300),          # x / y
              text_for_img,
              (0,0,0),           # rgb
              font=font)
    
    # Arial font source: '/Library/Fonts/Arial.ttf'
    
    
    # draw title
    """
    title_numbers = make_image_numbers(155)
    font = ImageFont.truetype('/Library/Fonts/IBM Plex Sans.ttf', 120)
    draw = ImageDraw.Draw(img)
    draw.text((60, 120),          # x / y
              str(image_iter+1),
              (0,0,0),           # rgb
              font=font)
    """
    
    
    # add title number from image
    offset = (60, 120)
    print(image_iter)
    index_number_image = make_image_numbers(image_iter+1)
    img.paste(index_number_image, offset)
    

    plt.imshow(img)
    plt.show()
    
    images_store.append(img)
# Out:
# ['Alice was beginning to get very tired', 'of sitting by her sister on the', 'bank, and of having nothing to do:', 'once or twice she had peeped into', 'the book her sister was reading,', 'but it had no pictures or conversations', 'in it, “and what is the use', 'of a book,” thought Alice “without', 'pictures or conversations?”']
# 0
# ['So she was considering in her own', 'mind (as well as she could, for the', 'hot day made her feel very sleepy', 'and stupid), whether the pleasure', 'of making a daisy-chain would', 'be worth the trouble of getting', 'up and picking the daisies, when', 'suddenly a White Rabbit with pink', 'eyes ran close by her.']
# 1
# ...

# %%
#Image.save(images_store[0], 'first.jpg')
for i in range(len(images_store)):
    images_store[i].save('output_images/' + str(i+1) + '.jpg')

# %%
image_iter = 1

text = alice[image_iter]


# split text into words
words = text.split(' ')


nchars = len(text)

### scaling lines and font sizes
if nchars < 300:
    line_count = math.ceil(math.pow(nchars,0.5) / 2)
    line_len = math.ceil(nchars / (line_count))
    font_size = math.ceil(60 / math.pow(line_count,0.5) * 3)

elif nchars < 600:
    line_count = math.ceil(math.pow(nchars,0.5) / 2)
    line_len = math.ceil(nchars / (line_count))
    font_size = math.ceil(50 / math.pow(line_count,0.5) * 2.8)

elif nchars < 750:
    line_count = math.ceil(math.pow(nchars,0.5) / 2)
    line_len = math.ceil(nchars / (line_count))
    font_size = math.ceil(42 / math.pow(line_count,0.5) * 2.8)

else:
    line_count = math.ceil(math.pow(nchars,0.5) / 2)
    line_len = math.ceil(nchars / (line_count))
    font_size = math.ceil(42 / math.pow(line_count,0.5) * 2.8)

####if chars low...
#font size = bigger
#line_len = smaller
#line_count = smaller


# splitting text onto multiple rows
lines = []
for i in range(line_count):
    lines.append(text[i*line_len:(i+1)*line_len])
    
# moving rest of text to next row


print(lines)


for z in range(len(lines)):

    line = lines[z]
    line.split(' ')


    for i in range(len(line)):
        
        ix = len(line) - i - 1
        if len(line) > line_len:
            if lines[z][ix-1] == ' ':

                if z == len(lines):
                    print(lines[z+1])
                    lines[z+1] = ''


                current = lines[z][:ix]
                rest = lines[z][ix:]
                print(rest)
                print(lines[z])

                try:
                    lines[z+1] = rest + '' + lines[z+1]
                except:
                    lines[z+1] = rest

                break
            
            
        
        
        #print(i)
        """
        ix = len(lines[z]) - i  # so traverse backwards down the line
        if lines[z][ix-1] == ' ':

            print(lines[z])
            if z == len(lines):
                lines[z+1] = ''

            current = lines[z][:i]
            rest = lines[z][i:]
            lines[z] = current
            lines[z+1] = rest + ' ' + lines[z+1]
            break
"""
# Out:
# ['So she was considering in her own', ' mind (as well as she could, for ', 'the hot day made her feel very sl', 'eepy and stupid), whether the ple', 'asure of making a daisy-chain wou', 'ld be worth the trouble of gettin', 'g up and picking the daisies, whe', 'n suddenly a White Rabbit with pi', 'nk eyes ran close by her.']

# %%
img_array = np.asarray(images_store[0])
img_array.shape
# Out:
# (1050, 1050, 3)

# %%
# Stroke Width Transform: whatever 
swtl = SWTLocalizer()


# 
swtl.swttransform(image=img_array, text_mode = 'lb_df',
                  save_results=True, #save_rootpath = 'swtres/',
                  minrsw = 3, maxrsw = 20, max_angledev = np.pi/3)
imgshow(swtl.swtlabelled_pruned13C)
# Out:
# Transforming...
# Operation Completed!

# %%
# Grouping
respacket=swtl.get_grouped(lookup_radii_multiplier=0.9, ht_ratio=3.0)
grouped_annot_bubble = respacket[2]
maskviz = respacket[4]
maskcomb  = respacket[5]

# Saving the results
_=cv2.imwrite('img1_processed.jpg', swtl.swtlabelled_pruned13C)
imgshowN([maskcomb, grouped_annot_bubble], savepath='grouped_img1.jpg')

# %%
swtl.swttransform(image=img_array, save_results=True, save_rootpath='swtres/',
                  edge_func = 'ac', ac_sigma = 1.0, text_mode = 'lb_df',
                  gs_blurr=True, blurr_kernel = (5,5), minrsw = 3, 
                  maxCC_comppx = 10000, maxrsw = 200, max_angledev = np.pi/6, 
                  acceptCC_aspectratio = 5.0)
# Out:
# Transforming...
# Operation Completed!

# %%
x

# %% [markdown]
# ## The rest of this is not used
#
# Keeping for posterity

# %%
response = requests.get("https://www.gutenberg.org/cache/epub/11/pg11-images.html")
corpus = response.text

# %%
start = re.search("Alice was beginning to get very", corpus).start()
end = re.search("THE END", corpus).start()

main_body = corpus[start:end]
main_body = main_body.replace('<i>', '')  # removing italics labels
main_body = main_body.replace('</i>', '')
main_body = main_body.replace('\xa0', '')
main_body = main_body.replace('</p>\r\n<p class="asterism">*******<br>\r\n<br>\r\n******<br>\r\n<br>\r\n*******<br></p>\r\n</div>\r\n<!--end chapter-->\r\n<div class="chapter">\r\n<h2>\r\n', '')
main_body = main_body.replace('</p>\r\n<p class="asterism">*******<br>\r\n<br>\r\n******<br>\r\n<br>\r\n*******<br>', '')

main_body = main_body.replace('\r\n        ', ' ')
main_body = main_body.replace('\r\n       ', ' ')
main_body = main_body.replace('\r\n      ', ' ')
main_body = main_body.replace('\r\n     ', ' ')
main_body = main_body.replace('\r\n    ', ' ')
main_body = main_body.replace('\r\n   ', ' ')
main_body = main_body.replace('\r\n  ', ' ')
main_body = main_body.replace('\r\n ', ' ')


main_body = main_body.replace('<a id="chap02"></a>CHAPTER II.<br>\r\nThe Pool of Tears</h2>\r\n<p>', ' ')
main_body = main_body.replace('</p>\r\n</div>\r\n<!--end chapter-->\r\n<div class="chapter">\r\n<h2>\r\n<a id="chap03"></a>CHAPTER III.<br>\r\nA Caucus-Race and a Long Tale</h2>\r\n<p>', ' ')



paragraphs = main_body.split('</p>\r\n<p>')

'</p>\r\n<p class="asterism">'


#sentence_count = np.sum([len(x.split('.')) for x in paragraphs])

paragraphs
# Out:
# ['Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, “and what is the use of a book,” thought Alice “without pictures or conversations?”',
#  'So she was considering in her own mind (as well as she could, for the hot day made her feel very sleepy and stupid), whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her.',
# ...

# %%
# look at para len
lens = [len(x) for x in paragraphs]
plt.hist(lens, bins = 100)
plt.show()
